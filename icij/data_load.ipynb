# %% [markdown]
# # ICIJ analysis

# %% [markdown]
# ## Set up

# %% [markdown]
# Load the Python dependencies.

# %%
from collections import Counter
from dataclasses import dataclass, field
import json
import os
import pathlib
import re
import sys
import typing

from icecream import ic
from tqdm import tqdm
import kuzu
import pandas as pd
import watermark

# %load_ext watermark

# %%
# %watermark
# %watermark --iversions
# Out:
# Last updated: 2024-07-07T19:23:05.161405-07:00
#
# Python implementation: CPython
# Python version       : 3.11.9
# IPython version      : 8.26.0
#
# Compiler    : Clang 13.0.0 (clang-1300.0.29.30)
# OS          : Darwin
# Release     : 23.5.0
# Machine     : arm64
# Processor   : arm
# CPU cores   : 14
# Architecture: 64bit
#
# kuzu     : 0.4.2
# sys      : 3.11.9 (v3.11.9:de54cf5be3, Apr  2 2024, 07:12:50) [Clang 13.0.0 (clang-1300.0.29.30)]
# json     : 2.0.9
# watermark: 2.4.3
# pandas   : 2.2.2
# re       : 2.2.1

# %% [markdown]
# Establish a connection to KùzuDB

# %%
# !rm -rf ./demo

# %%
db: kuzu.database.Database = kuzu.Database("./demo")
conn: kuzu.database.Database = kuzu.Connection(db)

# %% [markdown]
# ## Data discovery

# %%
dat_dir: pathlib.Path = pathlib.Path("full_2023")

# %% [markdown]
# ### Entities

# %%
dat_file: pathlib.Path = dat_dir / "nodes-entities.csv"

df = pd.read_csv(
    dat_file,
    header = 0,
    low_memory = False,
).astype(str).fillna("")

df.replace({"nan": ""}, regex=True, inplace=True)

df.head()
# Out:
#     node_id                                         name  \
# 0  10000001     TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1  10000002  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2  10000003                           HOTFOCUS CO., LTD.
# 3  10000004              SKY-BLUE GIFTS & TOYS CO., LTD.
# 4  10000005         FORTUNEMAKER INVESTMENTS CORPORATION
#
#                                  original_name former_name jurisdiction  \
# 0     TIANSHENG INDUSTRY AND TRADING CO., LTD.                      SAM
# 1  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.                      SAM
# 2                           HOTFOCUS CO., LTD.                      SAM
# 3              SKY-BLUE GIFTS & TOYS CO., LTD.                      SAM
# 4         FORTUNEMAKER INVESTMENTS CORPORATION                      SAM
#
#   jurisdiction_description company_type  \
# 0                    Samoa
# 1                    Samoa
# 2                    Samoa
# 3                    Samoa
# 4                    Samoa
#
#                                              address internal_id  \
# 0  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1001256.0
# 1  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1001263.0
# 2  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1000896.0
# 3  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1000914.0
# 4  LOYAL PORT LIMITED 8/F; CRAWFORD TOWER 99 JERV...   1001266.0
#
#   incorporation_date  ... struck_off_date dorm_date         status  \
# 0        23-MAR-2006  ...     15-FEB-2013                Defaulted
# 1        27-MAR-2006  ...     15-FEB-2014                Defaulted
# 2        10-JAN-2006  ...     15-FEB-2012                Defaulted
# 3        06-JAN-2006  ...     15-FEB-2009                Defaulted
# 4        19-APR-2006  ...     15-FEB-2008            Changed agent
#
#   service_provider  ibcRUC country_codes  countries       sourceID  \
# 0  Mossack Fonseca   25221           HKG  Hong Kong  Panama Papers
# 1  Mossack Fonseca   25249           HKG  Hong Kong  Panama Papers
# 2  Mossack Fonseca   24138           HKG  Hong Kong  Panama Papers
# 3  Mossack Fonseca   24012           HKG  Hong Kong  Panama Papers
# 4  Mossack Fonseca  R25638           HKG  Hong Kong  Panama Papers
#
#                                       valid_until note
# 0  The Panama Papers data is current through 2015
# 1  The Panama Papers data is current through 2015
# 2  The Panama Papers data is current through 2015
# 3  The Panama Papers data is current through 2015
# 4  The Panama Papers data is current through 2015
#
# [5 rows x 21 columns]

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#          node_id    name original_name former_name jurisdiction  \
# count     814344  814344        814344      814344       814344
# freq           1      29        424822      807507       209634
# unique    814344  781569        368821        6783          103
# top     10000001                                            BAH
#
#        jurisdiction_description company_type address internal_id  \
# count                    814344       814344  814344      814344
# freq                     209713       675593  515021      424822
# unique                       88           66   20583      343795
# top                     Bahamas
#
#        incorporation_date  ... struck_off_date dorm_date  status  \
# count              814344  ...          814344    814344  814344
# freq                25874  ...          470501    794137  456310
# unique              19009  ...            9083       276      86
# top                        ...
#
#        service_provider  ibcRUC country_codes countries       sourceID  \
# count            814344  814344        814344    814344         814344
# freq             470258  251878        309353    309353         213634
# unique                5  511469          1102      1103             22
# top                                                      Panama Papers
#
#                                            valid_until    note
# count                                           814344  814344
# freq                                            213634  772569
# unique                                              65     207
# top     The Panama Papers data is current through 2015
#
# [4 rows x 21 columns]

# %% [markdown]
# What are the `type` field values?

# %%
set(df.company_type.values)
# Out:
# {'',
#  'Antigua',
#  'Audit Licence',
#  'BVI Share Trust',
#  'BVI Sundry Entities (one off transactions)',
#  'BVI Trust',
#  'Bahamas IBC',
#  'Belize International Business Company',
#  'Busines Company Limited by Shares & Guarantee',
#  'Business Company Limited by Guarantee',
#  'Business Company Limited by Shares',
#  'Business Company Restricted Purposes',
#  'Business Corporation',
#  'Business Vehicle',
#  'CAP 285',
#  'Client Sundry Account',
#  'Collective Investment Scheme',
#  'Cook Islands Asset Protection Trust',
#  'Cook Islands Asset Protection Trust - 3520A',
#  'Cook Islands Trust',
#  'Domestic Company',
#  'EXEMPT INSURANCE HOLDING REGISTER',
#  'EXEMPT INSURANCE REGISTER',
#  'Foreign Company',
#  'Foreign Company Transfer',
#  'Holding Company',
#  'Hong Kong',
#  'Hong Kong Trust',
#  'International Business Corporation',
#  'International Company',
#  'International Trust',
#  'Limited Liability Company',
#  'Limited Partnership',
#  'Liquidator Licence',
#  'Mail Forwarding Only',
#  'Mauritius - Hybrid',
#  'Mauritius - International',
#  'Mauritius - Offshore',
#  'Mutual Fund',
#  'Mutual Fund Administrator',
#  'Mutual Fund Manager',
#  'Nevis - Limited Liability Company',
#  'Nevis Company',
#  'Nominee Only Entity',
#  'Panama - Foundation',
#  'Panama - IBC',
#  'Partnership',
#  'Private Company Limited By Shares',
#  'Private Mutual Fund',
#  'Private Trust Company',
#  'Professional Mutual Fund',
#  'Regular (Local) Company',
#  'SHIP REGISTRATIONS',
#  'Samoa',
#  'Seminar / Workshop',
#  'Seychelles',
#  'Singapore Trust',
#  'Standard - Redomiciled',
#  'Standard Company under IBC Act',
#  'Standard International Company',
#  'Sundry Account',
#  'The Forbes Group of companies for Express Co..',
#  'The GRA group of Companies for express Co.',
#  'Trust',
#  'Turks',
#  'UK Register'}

# %% [markdown]
# Keep track of the set of `node_id` values for this class.

# %%
id_entity: set = set(df.node_id.values)

# %% [markdown]
# After iterating the first time through this analysis, we return to this point and redefine an `Entity` node structure which is a superset of the fields defined among all of the Entity-ish nodes in ICIJ.
# See <https://docs.google.com/spreadsheets/d/1eSelhXhix_DtTZuzR2vfl_UdQlEwbwql6NZxqrtROxk/edit?usp=sharing>

# %%
conn.execute("""
  CREATE NODE TABLE Entity (
    node_id STRING,
    role STRING,
    name STRING,
    original_name STRING,
    former_name STRING,
    jurisdiction STRING,
    jurisdiction_description STRING,
    company_type STRING,
    address STRING,
    internal_id STRING,
    incorporation_date STRING,
    inactivation_date STRING,
    struck_off_date STRING,
    dorm_date STRING,
    status STRING,
    service_provider STRING,
    ibcRUC STRING,
    country_codes STRING,
    countries STRING,
    sourceID STRING,
    valid_until STRING,
    note STRING,
    vague BOOLEAN,
    PRIMARY KEY (node_id)
  )
""");

# %% [markdown]
# Reshape the dataframe to fit our inclusive `Entity` metadata.

# %%
df.columns.values.tolist()
# Out:
# ['node_id',
#  'name',
#  'original_name',
#  'former_name',
#  'jurisdiction',
#  'jurisdiction_description',
#  'company_type',
#  'address',
#  'internal_id',
#  'incorporation_date',
#  'inactivation_date',
#  'struck_off_date',
#  'dorm_date',
#  'status',
#  'service_provider',
#  'ibcRUC',
#  'country_codes',
#  'countries',
#  'sourceID',
#  'valid_until',
#  'note']

# %%
df.insert(1, "role", "Entity")

df["vague"] = False

df.head()
# Out:
#     node_id    role                                         name  \
# 0  10000001  Entity     TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1  10000002  Entity  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2  10000003  Entity                           HOTFOCUS CO., LTD.
# 3  10000004  Entity              SKY-BLUE GIFTS & TOYS CO., LTD.
# 4  10000005  Entity         FORTUNEMAKER INVESTMENTS CORPORATION
#
#                                  original_name former_name jurisdiction  \
# 0     TIANSHENG INDUSTRY AND TRADING CO., LTD.                      SAM
# 1  NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.                      SAM
# 2                           HOTFOCUS CO., LTD.                      SAM
# 3              SKY-BLUE GIFTS & TOYS CO., LTD.                      SAM
# 4         FORTUNEMAKER INVESTMENTS CORPORATION                      SAM
#
#   jurisdiction_description company_type  \
# 0                    Samoa
# 1                    Samoa
# 2                    Samoa
# 3                    Samoa
# 4                    Samoa
#
#                                              address internal_id  ...  \
# 0  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1001256.0  ...
# 1  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1001263.0  ...
# 2  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1000896.0  ...
# 3  ORION HOUSE SERVICES (HK) LIMITED ROOM 1401; 1...   1000914.0  ...
# 4  LOYAL PORT LIMITED 8/F; CRAWFORD TOWER 99 JERV...   1001266.0  ...
#
#   dorm_date         status service_provider  ibcRUC country_codes  countries  \
# 0                Defaulted  Mossack Fonseca   25221           HKG  Hong Kong
# 1                Defaulted  Mossack Fonseca   25249           HKG  Hong Kong
# 2                Defaulted  Mossack Fonseca   24138           HKG  Hong Kong
# 3                Defaulted  Mossack Fonseca   24012           HKG  Hong Kong
# 4            Changed agent  Mossack Fonseca  R25638           HKG  Hong Kong
#
#         sourceID                                     valid_until note  vague
# 0  Panama Papers  The Panama Papers data is current through 2015       False
# 1  Panama Papers  The Panama Papers data is current through 2015       False
# 2  Panama Papers  The Panama Papers data is current through 2015       False
# 3  Panama Papers  The Panama Papers data is current through 2015       False
# 4  Panama Papers  The Panama Papers data is current through 2015       False
#
# [5 rows x 23 columns]

# %%
conn.execute(
    "COPY Entity FROM (LOAD FROM df RETURN *)"
);

# %%
results = conn.execute("""
  MATCH (n:Entity)
  RETURN *
  LIMIT 1;
""")

while results.has_next():
    ic(results.get_next())
# Out:
# ic| results.get_next(): [{'_id': {'offset': 20480, 'table': 0},
#                           '_label': 'Entity',
#                           'address': '',
#                           'company_type': '',
#                           'countries': '',
#                           'country_codes': '',
#                           'dorm_date': '',
#                           'former_name': '',
#                           'ibcRUC': '93990B',
#                           'inactivation_date': '',
#                           'incorporation_date': '03-AUG-1999',
#                           'internal_id': '93990.0',
#                           'jurisdiction': 'BAH',
#                           'jurisdiction_description': 'Bahamas',
#                           'name': 'RICHFIELD CONSULTANCY SERVICES LIMITED',
#                           'node_id': '20093990',
#                           'note': '',
#                           'original_name': 'RICHFIELD CONSULTANCY SERVICES LIMITED',
#                           'role': 'Entity',
#                           'service_provider': '',
#                           'sourceID': 'Bahamas Leaks',
#                           'status': '',
#                           'struck_off_date': '10-APR-2003',
#                           'vague': False,
#                           'valid_until': 'The Bahamas Leaks data is current through early 2016.'}]

# %%
results = conn.execute("""
  MATCH (n:Entity)
  RETURN COUNT(*)
""")

while results.has_next():
    ic(results.get_next())
# Out:
# ic| results.get_next(): [814344]

# %% [markdown]
# ### Officers

# %%
dat_file: pathlib.Path = dat_dir / "nodes-officers.csv"

df = pd.read_csv(
    dat_file,
    header = 0,
    low_memory = False,
).astype(str).fillna("")

df.replace({"nan": ""}, regex=True, inplace=True)

df.head()
# Out:
#     node_id                  name    countries country_codes       sourceID  \
# 0  12000001            KIM SOO IN  South Korea           KOR  Panama Papers
# 1  12000002             Tian Yuan        China           CHN  Panama Papers
# 2  12000003  GREGORY JOHN SOLOMON    Australia           AUS  Panama Papers
# 3  12000004        MATSUDA MASUMI        Japan           JPN  Panama Papers
# 4  12000005           HO THUY NGA     Viet Nam           VNM  Panama Papers
#
#                                       valid_until note
# 0  The Panama Papers data is current through 2015
# 1  The Panama Papers data is current through 2015
# 2  The Panama Papers data is current through 2015
# 3  The Panama Papers data is current through 2015
# 4  The Panama Papers data is current through 2015

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#          node_id        name countries country_codes       sourceID  \
# count     771315      771315    771315        771315         771315
# freq           1       70873    302334        301057         238402
# unique    771315      538360      4091          4772             22
# top     12000001  THE BEARER                          Panama Papers
#
#                                            valid_until    note
# count                                           771315  771315
# freq                                            238402  767554
# unique                                              81      24
# top     The Panama Papers data is current through 2015

# %% [markdown]
# Note: phrases such as "THE BEARER" or "EL PORTADOR" are contract placeholders for whomever holds the bearer shares, and we need to filter them from entity resolution or constructing relations.

# %%
names: dict = df["name"].value_counts().to_dict()
names
# Out:
# {'THE BEARER': 70873,
#  'EL PORTADOR': 9325,
#  'Bearer 1': 2655,
#  'CARMICHAEL TREVOR A.': 1196,
#  'CLEMENTI LIMITED': 1111,
#  'TANAH MERAH LIMITED': 1046,
#  'BUKIT MERAH LIMITED': 963,
#  'CST ADMINISTRATION (BAHAM': 835,
#  'Bearer': 818,
#  'The Bearer': 813,
#  'THE CORPORATE SECRETARY LIMITED': 700,
#  'Christopher Marcus GRADEL': 576,
#  'BEARER': 537,
#  'COURT ADMINISTRATION LIMI': 474,
#  'PRIMARY MANAGEMENT LIMITE': 449,
#  'BARNES DEBORAH J.': 416,
#  'FIELDS JAMES A.': 408,
#  'BLUE SEAS ADMINISTRATION': 389,
#  'STANDARD NOMINEES (BAHAMA': 384,
#  "TRIDENT CORPORATE SERVICES (B'DOS) LTD": 369,
#  'CIRCLE CORPORATE SERVICES': 343,
#  'CORPORATE SERVICES LIMITED': 319,
#  'GUARDIAN NOMINEES (BARBADOS) LIMITED': 288,
#  'IL SHIN CORPORATE CONSULTING LIMITED': 286,
#  'KHAN ZARINA': 283,
#  'CASCADO AG': 275,
#  'OCTAGON MANAGEMENT LIMITE': 272,
#  'Vanessa Marie-Antoine PAYET': 259,
#  'AMICORP (BARBADOS) LTD.': 243,
#  'Shirley Sabia Therese VAN KERKHOVE': 242,
#  'MANEX LIMITED': 238,
#  'BDG MANAGEMENT LTD.': 231,
#  'SISNETT NATALIA B.': 230,
#  'WORME ROBERT C.': 220,
#  'CALLAGHAN DAVID F.': 219,
#  'COLYBRAND COMPANY SERVICES LIMITED': 216,
#  'C.B. MANAGEMENT LTD.': 215,
#  'C.B. STRATEGY LTD.': 213,
#  'International Administrators Limited': 211,
#  'TRUSS ARON DAVID': 209,
#  'Nominees One Limited': 206,
#  'Nominees Two Limited': 204,
#  'BOURQUE MARY ELLEN M.': 202,
#  'Songbird Limited': 202,
#  'ERASMUS MANAGEMENT LTD.': 193,
#  "AMICORP CORPORATE SERVICES (B'DOS) LTD": 184,
#  'FERREIRA ANDREW C.': 178,
#  'OSWALDO JESUS CISNEROS FAJARDO': 174,
#  'CARMICHAEL TREVOR A': 174,
#  'CHAPMAN STANLEY K.': 172,
#  'SKINNER CHRISTOPHER H.': 172,
#  'LA FALAISE MANAGEMENT LTD': 171,
#  'GTC MANAGEMENT LTD.': 169,
#  'Genevieve Odette Rona MAGNAN': 168,
#  'NOMARK LIMITED': 166,
#  'PRISM MANAGEMENT LIMITED': 164,
#  'SERVICES (BARBADOS) LTD. TRIDENT CORPORATE': 161,
#  'BSI MANAGEMENT LTD.': 159,
#  'Minor*': 159,
#  'KING DAVID N.': 157,
#  'Neesha Lynn KUMAR': 148,
#  'HARRIDYAL-SODHA LIZA A.': 147,
#  'PATEL MOHAMMED E.': 147,
#  'TARPUMBAY LIMITED': 145,
#  'BARATERRE LIMITED': 145,
#  'DIRMAC LIMITED': 144,
#  'DIZAME CONSULTING SA': 143,
#  'DILIGENTIA LTD.': 142,
#  'PATTERSON PETER MCG.': 138,
#  'MANEX LTD.': 133,
#  'MEDITERRANEAN MANAGEMENT': 128,
#  'CARICORP (BARBADOS) INC.': 126,
#  'REPULSE BAY LIMITED': 121,
#  'GREAVES STEPHEN L.': 118,
#  'CREDIT SUISSE TRUST LIMIT': 114,
#  'THE  BEARER': 114,
#  'THORNHILL ANDREW V.': 113,
#  'SILVERSTRAND BAY LIMITED': 113,
#  'DGM TRUST CORPORATION': 111,
#  'GENEVIEVE ODETTE RONA MAGNAN': 110,
#  'SHIRLEY SABIA THERESE VAN KERKHOVE': 108,
#  'BOURQUE ROBERT J.': 108,
#  'GITTENS THEODORE DAVID': 108,
#  'STAGRINTIE LIMITED': 107,
#  'RINTIEGAST LIMITED': 107,
#  'STEVMAR CORPORATE SERVICES LTD.': 106,
#  'PARKER STEVEN K.': 106,
#  'BETHEL OWEN': 106,
#  'TRIANGLE ADMINISTRATION L': 106,
#  'THOMPSON JOAN L.': 105,
#  'MONNARD PIERRE': 103,
#  'MAHABIR MARY J.': 103,
#  'SUMNER EDISON': 101,
#  'SKINNER BARRY M.': 101,
#  'CBT (BAHAMAS) LTD.': 101,
#  'Christodoulus G. Vassiliades & Co. LLC': 99,
#  'CORPORATE MANAGERS (BARBADOS) LTD.': 96,
#  'MARAJ RAMNATH H.': 96,
#  'DUNN GRAHAM J.': 96,
#  'GOSSELIN GILLES L.': 96,
#  'CLARKE MILLICENT': 95,
#  'DIZAME CONSULTING S.A.': 93,
#  'THOMSON KENNETH F.G.': 93,
#  'HOERKENS KARL': 92,
#  'CHARITABLE AND GOODWILL FOUNDATION': 92,
#  'NORTH ATLANTIC SERVICES LIMITED': 91,
#  'TRUST COMPANY OF BARBADOS LIMITED': 89,
#  'SMS LTD.': 89,
#  'THOMPSON TYSON W.': 88,
#  'GESTAM ADMINISTRATION LTD': 88,
#  'the bearer': 88,
#  'Alexandra MARANDEL': 87,
#  'CHANCERY CORPORATE SERVICES LIMITED': 87,
#  'GODET CONSTANCE': 86,
#  'APAKURA LLC': 86,
#  'CSUMRIK DAVID G.': 86,
#  'STERLING EAST LTD.': 84,
#  'LAWRENCE JOHN M.': 82,
#  'KNOWLES SONYA NICOLE': 82,
#  'WEBBER ANGELA R.': 81,
#  'SECRETARY LIMITED THE CORPORATE': 80,
#  'LUCAYA MANAGEMENT NOMINEE': 80,
#  'Bearer 2': 79,
#  'FORMIA LIMITED': 77,
#  'TRIDENT CORPORATE SERVICE (BARBADOS) LIMITED': 77,
#  'YEVGENIY FELD': 77,
#  'THOMPSON KATHY-ANN R-A.': 77,
#  'BAYSHORE DIRECTORS INC.': 77,
#  'The bearer': 76,
#  'FIRST COURT LIMITED': 76,
#  'GITTENS THEODORE D.': 76,
#  'MAYO NOMINEES LIMITED': 76,
#  'ASKAR ALSHINBAYEV': 75,
#  'PRIME MANAGEMENT SERVICES LIMITED': 75,
#  'WEEKES RYLE L.': 75,
#  'GODDARD COLIN G.': 74,
#  'BRATHWAITE ADRIEL D.': 74,
#  'ERASMUS MANAGEMENT LTD': 74,
#  'MAYO SECRETARIES LIMITED': 73,
#  'SERVICES (BARBADOS) LTD. AMICORP CORPORATE': 72,
#  'BOOS PETER N.': 72,
#  'FITZWILLIAM MICHAEL NEIL': 72,
#  'COLLINS MICHAEL': 72,
#  'Angela On Kei LEONG': 72,
#  'CLIFFORD WARREN': 72,
#  'DOUGLAS WILLIAM P.A.': 72,
#  'MONTAGUE EAST LTD.': 71,
#  'JONES SHIRELLE': 70,
#  'DE POURTALES PAUL': 70,
#  'GOSSET MANAGEMENT LTD': 69,
#  'Sylvie CHOLEWINSKA': 68,
#  'Jennifer GONTIER': 67,
#  'CRISTINA STUART GREEN': 67,
#  'EVELYN PETER R.P.': 67,
#  'VANESSA MARIE-ANTOINE PAYET': 66,
#  'RICHMOND NOMINEES LIMITED': 66,
#  'Company Kit Nominees Inc.': 66,
#  'GARDINER STUART JAMES': 65,
#  'CORPORATE SERVICES LTD. EIGHTH AVENUE': 65,
#  'BUKIT TANAH LIMITED': 64,
#  'CARTER PATRICIA HEATHER': 64,
#  'PEAT MARWICK ASSOCIATES LIMITED': 64,
#  'CHARLOTTE MANAGEMENT LTD': 64,
#  'Christopher Marcus Gradel': 63,
#  '': 63,
#  '(BARBADOS) LIMITED GUARDIAN NOMINEES': 62,
#  'TRIDENT CORPORATE SERVICE S (BARBADOS) LIMITED': 62,
#  'ALTMAN PAUL B.': 62,
#  'SMITH DAVID': 61,
#  'WARD JOSEPH W.': 60,
#  'FIELDS WAYNE I.': 60,
#  'DOUGLAS WILLIAM PETER A.': 60,
#  'AMICORP (BARBADOS) LTD': 58,
#  'Sylvie Erica HOAREAU-CHOLEWINSKA': 58,
#  'WILLIAMS RALPH S. DEC.': 58,
#  'BRUSSELS MANAGEMENT LTD.': 58,
#  'GAIRNS LTD.': 58,
#  'HANSCHELL CAROL': 58,
#  'DOUGLAS WILLIAM P. A.': 57,
#  'BOSFIELD NATHANIEL F.': 57,
#  'MEYER EDWARD A.': 57,
#  'MAYERS JOHN M.': 56,
#  'SECOND COURT LIMITED': 56,
#  'CAVERSHAM NOMINEES LIMITED': 56,
#  'BANNISTER YOLANDE A.L.': 55,
#  'NURZHAN SUBKHANBERDIN': 54,
#  'PAYNE LEONARD A.': 54,
#  'HIGHLAND RYAN A.': 54,
#  'BROCK NOMINEES LIMITED': 54,
#  '(BAHAMAS) LIMITED CST ADMINISTRATION': 53,
#  'MOHUL NOMINEES LIMITED': 53,
#  'LIMITED SECOND DIRECTORSHIPS': 53,
#  'TENBY NOMINEES LIMITED': 53,
#  'TOWNER CHRISTOPHER J.N.': 53,
#  'KASTEL LIMITED': 53,
#  'WILLIAMS CHARLES O.': 53,
#  'TO THE BEARER': 52,
#  'LEACH SHARON L.': 52,
#  'INTERCON LIMITED': 52,
#  'ALTUS LIMITED': 52,
#  'LIMITED FIRST DIRECTORSHIPS': 52,
#  'CAVERSHAM SECRETARIES LIMITED': 52,
#  'THORNHILL ANDREW VANROY': 52,
#  'LIVINGSTON GROUP S.A.': 51,
#  'AMICORP (BAHAMAS) LTD.': 51,
#  'BJERKHAMN BJORN F.': 51,
#  'JOSEPH VELLA': 51,
#  'BSI ADMINISTRATION LTD.': 51,
#  'HILLARD ENTERPRISES S.A.': 50,
#  'CLARKE GILLIAN M.H.': 50,
#  'TAGGART JULIA A.': 50,
#  'MINERVA NOMINEES LIMITED': 50,
#  'STANGUARD NOMINEES (BARBADOS) LIMITED': 50,
#  'GIBBS TONY': 49,
#  'Xin ZHOU': 49,
#  'EMTAGE STEPHEN E.': 49,
#  'SMITH NEVILLE L.': 49,
#  'WEETCH MICHAEL J.': 49,
#  'CHANDLER DENNIS H.L.': 49,
#  'HARRIDYAL-SODHA LIZA A': 49,
#  'BOYCE MICHAEL R.': 49,
#  'SMITH JENNIFER G.': 48,
#  'Harris Worldwide Ltd': 48,
#  'HAMILTON NOMINEES LIMITED': 48,
#  'BRATHWAITE VERE P.': 48,
#  'MCCLURG HAMISH G.': 48,
#  'JOSEPH CAMILLERI': 48,
#  'JOSEPH ZAMMIT': 48,
#  'MSI NOMINEES LTD.': 48,
#  'FARMER STEPHEN W.': 48,
#  'BSI TRUST CORPORATION (BA': 47,
#  'WORRELL LEODEAN': 47,
#  'DE LADURANTAYE ANDRE': 47,
#  'MARSHALL DALE DERMONT': 47,
#  'JOSEPH BORG': 47,
#  "IBC'S SERVICES INCORPORATED": 47,
#  'NAGAI TREVOR P.': 47,
#  'SERVICES LIMITED CHANCERY CORPORATE': 46,
#  'WALFORD PETER A.': 46,
#  'Olavinlinna Invest Oy': 46,
#  'BEATUS LIMITED': 46,
#  'JOSEPH FARRUGIA': 46,
#  'THE BAERER': 46,
#  'GEORGIOS DEMATHAS': 46,
#  'Suomenlinna Inter Oy': 46,
#  'ABG SECRETARY INC.': 45,
#  'BROTHERHOOD FOUNDATION': 45,
#  'FIELDS ALLAN CLIFFORD': 45,
#  'BISHOP IAN C.A.': 45,
#  'THRONEBURY ARLENE': 45,
#  'Shirley Sabia Therese Van Kerkhove': 45,
#  'TRIANON INCORPORATED': 45,
#  'EIGHTH AVENUE CORPORATE SERVICES LTD.': 45,
#  'SEALY RUPERT B.': 45,
#  'ELCAN NOMINEES LIMITED': 44,
#  'CANNON NOMINEES LIMITED': 44,
#  'METANI DIRECTION LIMITED': 44,
#  'CAVERSHAM HOLDINGS LIMITED': 43,
#  'REID ROBERT J.': 43,
#  'HAMILTON TRUSTEES LIMITED': 43,
#  'Jennifer Anne GONTIER': 43,
#  'Trident Trust Company (South Dakota) Inc': 43,
#  'INDER RIEDEN ANTHONY L.M.': 43,
#  'Matthew Charles Stokes': 43,
#  'HAMPDEN VINSTON E.': 43,
#  'CANNON INTERNATIONAL LIMITED': 43,
#  'INVESTA MANAGEMENT LIMITED': 43,
#  'KNIGHT RICARDO O.': 42,
#  'Bolsdoto Holdings Limited': 42,
#  'GOLD LION DIRECTOR SERVICES INC.': 42,
#  'PATEL MOHAMMED E': 42,
#  'Marie Alexandra Sherlaine MARANDEL': 42,
#  'NAUTILUS NOMINEE SERVICES LIMITED': 41,
#  'Management Group Limited': 41,
#  'MINERVA SERVICES LIMITED': 41,
#  'MOSSFON NOMINEES LIMITED': 41,
#  'IPCO S.A.': 41,
#  'CORPORATE MANAGERS (BARBADOS) LTD': 41,
#  'NELEX FINANCE SA': 41,
#  'WRIGHT DAVID O.': 41,
#  'L.G. SECRETARIES LIMITED': 40,
#  'HARRIS PETER V.': 40,
#  'WORKMAN JOAN Y.': 40,
#  'JOSE RICARDO POMA DELGADO': 40,
#  'Jesse Grant Hester': 40,
#  'CARIBBEAN CORPORATE SERVICES LTD.': 40,
#  'KONSTANTIN GRIGORISHIN': 40,
#  'SELETAR LIMITED': 40,
#  'HOLOWESKO LYNN P.': 39,
#  'SMITH CECIL A.B.': 39,
#  'ELLIS ANTHONY G.': 39,
#  'THOMAS BRUCE A.': 39,
#  'Ferdo A. Gil': 39,
#  'PRIMI LIMITED': 39,
#  'AL PORTADOR': 39,
#  'CARMICHAEL TREVOR AUSTIN': 38,
#  'JUMAN AZAZ KHAN': 38,
#  'JOHNSON RALPH L.': 38,
#  'Bearer 3': 38,
#  'GCS LTD.': 38,
#  'SCTS Capital Pte. Ltd': 38,
#  'Rodney Reddy MARENGO': 38,
#  'FIDELIS NOMINEES LIMITED': 38,
#  'KING DAVID N': 38,
#  'BYNOE CHRISTOPHER DAVID': 38,
#  'MARSHALL ANTHONY RICHARD S.': 37,
#  'EVANS CHRISTOPHER G.': 37,
#  'Baraterre Limited': 37,
#  'PARKER STEVEN K': 37,
#  'MAXWELL LIMITED': 37,
#  'CHELSTON DIRECTOR SERVICES INC.': 37,
#  'CRUIKSHANK ALLAN B.': 36,
#  'BTT Nominees (BVI) Ltd (ex ING Nominees (BVI) Ltd.': 36,
#  'WORO LTD.': 36,
#  'DAVIES DAWN E.': 36,
#  'BANNISTER YOLANDE A. L.': 36,
#  'ANA GIANNINA FASANELLI CAVALLAZZI': 36,
#  'PERREIRA KAREN ANN': 36,
#  'Stephen John Kelly': 36,
#  'Minerva Nominees Limited': 36,
#  'Integrity Directors Ltd': 36,
#  'METZGER JOHN H.': 35,
#  'COMPANY KIT NOMINEES INC.': 35,
#  'RICARDO JOSE CISNEROS RENDILES': 35,
#  'Tarpumbay Limited': 35,
#  'GEOFFREY MAGISTRATE': 35,
#  'MEYER EDWARD ADRIAN': 35,
#  'BOS NOMINEES (JERSEY) LIMITED': 35,
#  'TEMPRO PHILIP G.': 35,
#  'FORBES HELEN A.': 35,
#  'JOSEPH MICALLEF': 35,
#  'DOTTIN MAUREEN ELIZABETH': 35,
#  'Victor Joseph Vandewater': 35,
#  'MS. LEONG ANGELA ON KEI': 35,
#  'SOCIEDAD DE DIRECTORIA CE': 35,
#  'C B MANAGEMENT LTD.': 35,
#  'C B STRATEGY LTD.': 35,
#  'BASTIAN ANTOINE': 35,
#  'Raul Garrido Garibaldo': 35,
#  'THOMPSON TYSON W': 35,
#  'LIMITED WELWYN': 35,
#  '???': 35,
#  'BESTER DAVID HERMANUS': 34,
#  'NAUTILUS CORPORATE SERVICES LIMITED': 34,
#  'BUKTI TANAH LIMITED': 34,
#  'FERREIRA ANDREW C': 34,
#  'CLARKE HAZEL PAMELA': 34,
#  'SCTS Management Pte. Ltd': 34,
#  'Eurotrade Nominees Ltd.': 34,
#  'JONES JOHN-PAUL': 34,
#  'Joseph Sparks': 34,
#  'PILE AMANDA J.': 34,
#  'IMPERIAL MANAGEMENT SERVICES LTD': 34,
#  'BOS SECRETARIES (JERSEY) LIMITED': 33,
#  'WORD LTD.': 33,
#  'FENCHURCH TRUST LIMITED': 33,
#  'Bernard Loh See Fun': 33,
#  'Si Bodmer': 33,
#  'UNICO LIMITED': 33,
#  'GREAVES STEPHEN L': 33,
#  'Genevieve Odette Rona Mag': 33,
#  'Ferdo A. GIL': 33,
#  'OFFSHORE SOLUTIONS INC.': 33,
#  'COZIER FRANCIS S.': 32,
#  'THOMSON KENNETH F. G.': 32,
#  'CARMICHAEL* TREVOR A.': 32,
#  'Un Chan CHAN': 32,
#  'ZHANG WEI': 32,
#  'MTB Clients Nominees Limited': 32,
#  'HARPO S.A.': 32,
#  'SERANGOON LIMITED': 32,
#  'LASHLEY AMANDA J.': 32,
#  'STICHTING SALISBURY': 32,
#  'THE CORPORATE SECRETARY* LIMITED': 32,
#  'HORNBEAM CORP.': 32,
#  'HOYOS ANTHONY C.': 32,
#  'SMS LTD': 32,
#  'ABDULLAH AL SHARIF AL HUSSEIN': 32,
#  'VLADIMIR CHERNUKHIN': 32,
#  'SKINNER CHRISTOPHER H': 32,
#  'ACTON FINANCIAL SERVICES LIMITED': 32,
#  'MILLINGTON DAVID A.': 32,
#  'JOSEPH GALEA': 31,
#  'JONES RONALD W.': 31,
#  'MURRAY COLIN D.': 31,
#  'MFM FOUNDATION': 31,
#  'BLACKMAN CHRISTOPHER A.': 31,
#  'CORPORATE SERVICES* LIMITED': 31,
#  'BOYNE LIMITED': 31,
#  'DELANY DUSTIN D.P.': 31,
#  'PINE GROVE FOUNDATION': 31,
#  'COLE HAROLD L.': 31,
#  'Cannon Nominees Limited': 31,
#  'NOMIHOLD SECURITIES INC.': 31,
#  'SERRAO PHILIP EVAN': 31,
#  'FAIR IAN D.': 31,
#  'ORION NOMINEES LIMITED': 31,
#  'COURT ADMINISTRATION LTD.': 31,
#  'Formia Limited': 31,
#  'REFAEL EDRY': 31,
#  'ADMINISTRA INC.': 31,
#  'HALOUTE ELIAS': 31,
#  'BUSINESS MANAGEMENT LIMIT': 31,
#  'Minerva Services Limited': 30,
#  'MAHABIR MARY J': 30,
#  'PENSHORE EQUITIES CORP.': 30,
#  'MANSOUR ABDELMEGEED MANSOUR AMER': 30,
#  'FROST FRANCES ALISON': 30,
#  'MCKAY ANDREW A.': 30,
#  'Barbara Chatterton': 30,
#  'TINDALE DAVID': 30,
#  'BLACKETT SHERENE N.': 30,
#  'AMICORP CORPORATE SERVICE (BARBADOS) LTD.': 30,
#  'INNISS DONVILLE O.': 30,
#  'BANKHILL LIMITED': 30,
#  'KHAN MOHAMED H.': 30,
#  'FIELDS THEROLD O`N': 30,
#  'Herna Rita CHARLES': 30,
#  'UCE SECRETARIES S.A.': 30,
#  'SISNETT NATALIA B': 30,
#  'Cannon International Limited': 30,
#  'GALE BARRY LOUIS VALENCE': 30,
#  'Bearer 4': 30,
#  'CBT SECRETARIAL SERVICES': 30,
#  'MS. STELLA G. PORT-LOUIS': 30,
#  'TOMLIN WILLIAM M.': 30,
#  'Thomas Chatterton': 29,
#  'DAMOR INVESTMENTS LIMITED': 29,
#  'JAIME GILINSKI BACAL': 29,
#  'GALE BARRY L.V.': 29,
#  'THE GENERAL FIDUCIARY COMPANY LIMITED': 29,
#  'MOORES NOMINEES LIMITED': 29,
#  'LED SERVICES ESTABLISHMENT': 29,
#  'WALCOTT STEPHEN JOHN': 29,
#  'TREX LIMITED': 29,
#  'GONSALVES LESLIE T.': 29,
#  'NICHOLLS PHILIP V.': 29,
#  'CLARKE ALFRED H.': 29,
#  'GODDARD JOSEPH N.': 29,
#  'THANI ABDULLA T.J. AL THANI': 29,
#  'BREWER COLIN T.O.': 29,
#  'NORMAN BENITO FIORE': 28,
#  'CLARKE BRIAN H.': 28,
#  'GEORGIOS KANTAS': 28,
#  'MOSSFON SUBSCRIBERS LTD.': 28,
#  'HEWITT KENNETH R.': 28,
#  'BYNOE CHRISTOPHER D.': 28,
#  'CRICHLOW NICHOLAS C.': 28,
#  'SOCIEDAD LATINA DE MANAGE': 28,
#  'BRATHWAITE ADRIEL D': 28,
#  'WILLIAMS CLYDE Q.': 28,
#  'WEBSTER DELIA': 28,
#  'CAFFERATA JEREMY A.C.': 28,
#  'MARIA DEL PILAR AROSEMENA DE ALEMAN': 28,
#  'JONES MELANIE S.': 28,
#  'OLGA BOGOMAZOVA': 28,
#  'FARMER STEPHEN WILFRED': 28,
#  'MIKAIL GUTSERIEV': 28,
#  'SMITH NEVILLE LEROY': 28,
#  'SKINNER BARRY M': 28,
#  'BASEL ONE LIMITED': 28,
#  'PETER JOHN GOULANDRIS': 28,
#  'INTERCON NOMINEES LIMITED': 28,
#  'NORTHQUAY LIMITED': 28,
#  'COURT ADMINISTRATION': 27,
#  'DELANY DUSTIN DAVID PHILLA': 27,
#  'SARNIA MANAGEMENT LTD.': 27,
#  'Denys Meade Laurence': 27,
#  'FALCON NOMINEES LIMITED': 27,
#  'TRAFALGAR NOMINEES LIMITED': 27,
#  'CORPORATE NOMINEES LIMITED': 27,
#  'CACIQUE INVESTMENTS LIMITED': 27,
#  'WAI FUNG CHEUNG': 27,
#  'YAHYA NADIA A.': 27,
#  'JOSEPH MUSCAT': 27,
#  'MIKAIL SHISHKHANOV': 27,
#  'DELMAS FRERE FRANCIS C.': 27,
#  'CAVE RONALD GEOFFREY': 27,
#  'WANG WEI': 27,
#  'BOURQUE ROBERT J': 27,
#  'YOUNG PHILIP S.': 27,
#  'WILLIAMS JOHN M.B.': 27,
#  'Silver Zone Management Inc.': 27,
#  "Raymond O'Reilly": 27,
#  'MEINIG WALTER P.': 27,
#  'Vanessa Marie-Antoine Payet': 27,
#  'SZE HOI KWAI': 27,
#  'GOODING ROGER D.': 27,
#  'CHEN WEI': 27,
#  'ROLIKA INC.': 27,
#  'Stratford Management Ltd': 27,
#  'WEATHERHEAD BERNARD ANTHONY': 27,
#  'JOSHUA CARL BELL': 26,
#  'American Corporate Services, Inc. (USA)': 26,
#  'DANIEL DEREK L.': 26,
#  'ROSENBLOOM ALLAN': 26,
#  'STEINBOK JOSEPH': 26,
#  'DEFREITAS PETER E.': 26,
#  'HANCOCK STEPHEN': 26,
#  'BOS Secretaries (Jersey) Limited': 26,
#  'BDG MANAGEMENT LTD': 26,
#  'BENEFICENCE FOUNDATION': 26,
#  'JOHN BORG': 26,
#  'TOPPIN PATRICK B.': 26,
#  "BAYSHORE CORPORATE SERVICES (B'DOS) LTD": 26,
#  'NWT NOMINEES LIMITED': 26,
#  'BRATHWAITE JONATHAN J.K.': 26,
#  'MCEVOY DAVID I.': 26,
#  'ODLE PETER JULIAN': 26,
#  'ATC ADMINISTRATORS INC.': 26,
#  'GALIMZHAN YESSENOV': 26,
#  'KHAN MOHAMED HAFIZ': 26,
#  'DGM BANK & TRUST INC.': 26,
#  'PATEL NAEEM A. E.': 26,
#  'MAYFAIR NOMINEES LIMITED': 26,
#  'SERGEY ALEXANDROVICH PUGACHEV': 26,
#  'VALEA GOODWILL FOUNDATION': 26,
#  'J.W. BUSINESS SERVICES INC.': 26,
#  'JOSEPH AZZOPARDI': 26,
#  'SYLVIE ERICA HOAREAU-CHOLEWINSKA': 26,
#  'BLADES BARRY G.': 26,
#  'FIDEHOLD MANAGEMENT LTD.': 25,
#  'HUTCHINSON IAN STC.': 25,
#  'ALLIANCE CORPORATE SERVICES LIMITED': 25,
#  'ANTHONY CAMILLERI': 25,
#  'CDA LTD.': 25,
#  'MARAJ RAMNATH HANSRAJ': 25,
#  'DORCHESTER INTERNATIONAL INC.': 25,
#  'CDB LTD.': 25,
#  'El Portador': 25,
#  'MAGNUS NOMINEES LIMITED': 25,
#  'ALLEYNE EZRA E.': 25,
#  'SCIVIAS TRUST MANAGEMENT LIMITED': 25,
#  'HELM TRUST COMPANY LIMITED': 25,
#  'ENERVO ADMINISTRATION LIM': 25,
#  'GITTENS THEODORE D': 25,
#  'JOSEPH GRECH': 25,
#  'Edward Petre-Mears': 25,
#  'LI JUN': 25,
#  'CMS LIMITED': 25,
#  'PEMBERTON MICHAEL BARRIE': 25,
#  'AMICORP CORPORATE SERVICE S (BARBADOS) LTD.': 25,
#  'BLACKMAN CHRISTOPHER ARTHUR': 25,
#  'H2R NOMINEE FOUNDATION': 25,
#  'Stephen Kelly': 25,
#  'PADDICK BRENDAN J.': 25,
#  'RUSLAN GORYUKHIN': 25,
#  'MOSSACK FONSECA & CO. (B.V.I.) LTD.': 25,
#  'JOSEPH ATTARD': 25,
#  'Juris Magister (BVI) Ltd.': 25,
#  'BEXANA CORPORATION': 25,
#  'H G M SERVICES LIMITED': 25,
#  'Andreas Thomas Moustras': 25,
#  'WEATHERHEAD BERNARD ALFREDO': 25,
#  'KPM Consulting Ltd.': 25,
#  'TRIDENT CORPORATE SERVICES (BDOS) LTD.': 24,
#  'KEESTON CORPORATION': 24,
#  'KIRTON WAYNE H.': 24,
#  'SCIVIAS TRUST MANAGEMENT LTD': 24,
#  'LUIS JAVIER CASTRO LACHNER': 24,
#  'Demetra Stavrinou': 24,
#  'BOS Nominees (Jersey) Limited': 24,
#  'REECKMANN S.A.': 24,
#  'OSS ADVISORS INC.': 24,
#  'LIU YANG': 24,
#  'PRITCHARD MARTIN J.K.': 24,
#  'JOSEPH AGIUS': 24,
#  'SHOREY DAVID C.': 24,
#  'Red Shield Nominees Limited': 24,
#  'BOURNE CARL L.': 24,
#  'ORBITRON LIMITED': 24,
#  'GOLLOP FRED W.': 24,
#  'Regula Limited': 24,
#  'Edgardo E. Diaz': 24,
#  'BUSINESS, LTD. GFS': 24,
#  'Richmond Nominees Limited': 24,
#  'ALLSOPP JUNIOR O.': 24,
#  'BLUE SPRUCE FOUNDATION': 24,
#  'GTC MANAGEMENT LTD.,': 24,
#  'Executive Nominees (BVI) Ltd': 24,
#  'AMOS SERVICES S.A.': 24,
#  'NORRIS JULIAN D.': 24,
#  'Norma Laurence': 23,
#  'LEX CARIBBEAN': 23,
#  'ECS INTERNATIONAL NOMINEES (BVI) LIMITED': 23,
#  'MILLIGAN SIMON G.': 23,
#  'BAIRD ONE LIMITED': 23,
#  'CSUMRIK DAVID G': 23,
#  'JOSEPH MIFSUD': 23,
#  'HEWITT MITCHINSON E.S.': 23,
#  'MURRAY ANDREW D.': 23,
#  'MARK CAMILLERI': 23,
#  'BASEL TWO LIMITED': 23,
#  'JACKMAN ERNEST W.': 23,
#  'Lerato Makoetlane': 23,
#  'CHRISTEN MARTIN': 23,
#  'Irene Knowles': 23,
#  'JDS SECRETARIES LIMITED': 23,
#  'GRIMES MICHAEL D.': 23,
#  'MALONEY MARK ALBERT': 23,
#  'THORNHILL ANDREW V': 23,
#  'PATTERSON* PETER MCG.': 23,
#  'WORME ROBERT C': 23,
#  'SAIT SALAM GUTSERIEV': 23,
#  'HUTCHINSON GAYLE A.': 23,
#  'STEINBOK JEREMIAH': 23,
#  'MARR ROSEMARY ELIZABETH': 23,
#  'CAVE ROGER M.': 23,
#  'KINGSTON PHILIP H.': 23,
#  'STEVMAR CORPORATE SERVICES LTD': 23,
#  'COMSEC SERVICES LIMITED': 23,
#  "GUARDIAN NOMINEES (B'DOS) LIMITED": 23,
#  'BJERKHAMN BJORN FERDINAND': 23,
#  'Yuk Wah CHAN NG': 22,
#  'PIETRO CARENZA': 22,
#  'MAYERS RODNEY ST.C.': 22,
#  'CHESTERFIELD NOMINEES LIMITED': 22,
#  'WALCOTT STEPHEN J.': 22,
#  'ATHNID LIMITED': 22,
#  'Andreas T Moustras': 22,
#  'BELLAMY JOHN G.': 22,
#  'FYNALIST LIMITED': 22,
#  'First Court Limited': 22,
#  'JOSEPH DEBONO': 22,
#  'BINNEMA HENRY H.': 22,
#  'GROUPWISE LIMITED': 22,
#  'AMBASSADOR SECRETARIES LI': 22,
#  'HIGHLAND RYAN A': 22,
#  'YEARWOOD VINCENT L.': 22,
#  'Douglas Mackintosh': 22,
#  'ANDRI ATHANASIOU': 22,
#  'Cambridge Hills Ltd': 22,
#  'CAVE RONALD G.': 22,
#  'AZTEC HOLDINGS LIMITED': 22,
#  'KODILINYE LYSTRA A.': 22,
#  'BLANCHETTE RICHARD A.': 22,
#  'ANTHONY BORG': 22,
#  'BRYANT HILDA DIANA': 22,
#  'SERGEY PUGACHEV': 22,
#  'LEDGER IAN': 22,
#  'HOLFORD ROGER S.': 22,
#  'BRONTE INTERNATIONAL SA': 22,
#  'Intercon Limited': 22,
#  'JOSEPH CARUANA': 22,
#  'MATIAS RODRIGO DE TEZANOS POSSE': 22,
#  'Michael Garnet Dixon': 21,
#  'MARIO BORG': 21,
#  'HAZZARD ALTHEA C.': 21,
#  'ARTHUR-SELMAN JAMAR P.R.': 21,
#  'CRUIKSHANK ALLAN B': 21,
#  'FLETCHER PETER G.': 21,
#  "O'GORMAN BARBARA A.": 21,
#  'NEWSAM DOUGLAS A.': 21,
#  'INNISS DONVILLE O': 21,
#  'JOHN CAMILLERI': 21,
#  'BRACE NATALIE MARIE': 21,
#  'IOSIF SANDLER': 21,
#  'FAITH FOUNDATION': 21,
#  'SYMMONDS PETER GLADWYN': 21,
#  'TAY YEW BENG PETER': 21,
#  'LI WEI': 21,
#  'MIREMONT NOMINEES LTD.': 21,
#  'VITALY YUSUFOV': 21,
#  'CREDIT SUISSE TRUST LTD.': 21,
#  'DOUGLAS WILLIAM P A': 21,
#  'SIMON CRISPIN GROOM': 21,
#  'GALE BARRY LOUIS VALANCE': 21,
#  'BTC NOMINEES S.A.': 21,
#  'YORBAY BUSINESS S.A.': 21,
#  'JOSEPH PACE': 21,
#  'SOLIDARITY ALLIANCE FOUNDATION': 21,
#  'Jason Hughes': 21,
#  'LA VILLE CORPORATE SERVICES LIMITED': 21,
#  'UNION BANCAIRE PRIVEE UBP S.A.': 21,
#  'PLANTATION MANAGEMENT LTD.': 21,
#  'CORPORATE SECRETARY LIMITED': 21,
#  'Aster Worldwide Limited': 21,
#  'GAURAV BURMAN': 21,
#  'MCDEIGAN-ELDRIDGE RHONDA D.': 21,
#  'ZHANG YONG': 21,
#  'DORCHESTER INTERNATIONAL INC': 21,
#  'HELM MANAGEMENT LIMITED': 21,
#  'ZHANG JUN': 21,
#  'TOWNER CHRISTOPHER J. N.': 21,
#  'JOSEPH PORTELLI': 21,
#  'HOLOWESKO & COMPANY LIMIT': 21,
#  'SUOMENLINNA INTER OY': 20,
#  'LIU NORMAN C.T.': 20,
#  'UNICO NOMINEES LIMITED': 20,
#  'PAUL VELLA': 20,
#  'EDGHILL CHARLES EDWIN': 20,
#  'Jenny Azolan': 20,
#  'ANTHONY VELLA': 20,
#  'CLARKE GILLIAN M. H.': 20,
#  'BASTIAN MR. ANTOINE': 20,
#  'CYRUS KIRK E.': 20,
#  'WANG QI': 20,
#  'ATLAS TRUST COMPANY (JERSEY) LIMITED': 20,
#  'NEWBOLD DAVID R.': 20,
#  'LI FENG': 20,
#  'BYER TREVOR OSCAR': 20,
#  'HERALD MANAGEMENT SERVICES LIMITED': 20,
#  'ANGLO NOMINEES LTD.': 20,
#  'GTC MANAGEMENT LTD': 20,
#  'BETHEL OWEN S-M.': 20,
#  'AMICORP CORPORATE SERVICES (BDOS) LTD.': 20,
#  'TEMPLE SECRETARIES LIMITED': 20,
#  'CHANDARIA KAPOOR': 20,
#  'Red Shield Secretaries Limited': 20,
#  'EDGHILL RICHARD L.V.': 20,
#  'SAID GUTSERIEV': 20,
#  'EDGHILL STEPHEN R.': 20,
#  'HERALD TRUST COMPANY LIMITED': 20,
#  'Terthur Trading Limited': 20,
#  'TURNEY GITTENS CLYDE': 20,
#  'HAINE S.A.': 20,
#  'WANG LEI': 20,
#  'SIMPSON KYFFIN DONALD': 20,
#  'Damian Calderbank': 20,
#  'SMITH NEVILLE LER.': 20,
#  'IOSSIF NATANOVICH SANDLER': 20,
#  'TRIDENT CORPORATE SERVICE': 20,
#  'KING GERALD A.': 20,
#  'BDG MANAGEMENT LTD.,': 20,
#  'HYDE KEISHA N.': 20,
#  'Don Di LAM': 20,
#  'IMPERIAL CORPORATE SERVICES LTD.': 20,
#  'CALLAGHAN DAVID F': 20,
#  'NORTH ATLANTIC SERVICES LTD.': 20,
#  'JOSEPH SAMMUT': 20,
#  'RAFFLES TOWNSHIP LTD.': 19,
#  'CHAPMAN STANLEY K': 19,
#  'JONES ROBERT L.': 19,
#  'NORDIC INVESTMENT GROUP LIMITED COMPANY': 19,
#  'KHAN* MOHAMED HAFIZ': 19,
#  'HINKSON GREGORY E.': 19,
#  'MATTHEW CHARLES STOKES': 19,
#  'CARLOS GERMAN CORDERO GONZALEZ': 19,
#  'BATSON ST. CLAIR A.': 19,
#  'WILLIAMS RALPH S.': 19,
#  'STOLLMEYER MARK SCOTT': 19,
#  'WILLIAMS VERNON A.': 19,
#  'Geoffrey Taylor': 19,
#  'IMPERIAL CORPORATE SERVICES LTD': 19,
#  'FOSTER JOHN DERECK': 19,
#  'CAMBRIDGE TRUST CO. LIMITED': 19,
#  'Seletar Limited': 19,
#  'FORDE SHURLAND M.': 19,
#  'Genevieve Odette RONA MAGNAN': 19,
#  'JOSEPH SCICLUNA': 19,
#  'Volaw Nominees One Limited': 19,
#  'SCORPIO SECRETARIAL SERVICES LIMITED': 19,
#  'YEARWOOD ALTHEA C.': 19,
#  'TRIDENT CORPORATE SERVICES (BARBADOS)': 19,
#  'MURPHY JOHN GORDON': 19,
#  'ABRAHAM JORGE HAZOURY TORAL': 19,
#  'JOHNSON RALPH LANCELOT': 19,
#  'KELLDYNE LTD.': 19,
#  'MIDLAND RESOURCES HOLDING LIMITED': 19,
#  'NEILANDS JOHN DAVID': 19,
#  'TRIDENT TRUST COMPANY (I.O.M.) LIMITED': 19,
#  'ANDREW DAMIAN PERL': 19,
#  'GUSTAVO ALFREDO CISNEROS RENDILES': 19,
#  'KIRBY ROBERT S.': 19,
#  'PATEL NAEEM AHMED EBRAHIM': 19,
#  'SIMPSON KYFFIN DAVID': 19,
#  'Bearer 5': 19,
#  'JOSEPH GAUCI': 19,
#  'ROLLE-TIEDEMANN SUSANNE': 19,
#  'CIRCLE TRUST LIMITED': 19,
#  'JOSEPH ABELA': 19,
#  'Anthony Paul GOLAMCO': 19,
#  'TOMAS FIALA': 19,
#  'LEX LTD.': 19,
#  'WILKINSON JOHN G.': 19,
#  'APEX NOMINEES 1 LIMITED': 19,
#  'Gina A. Martinez G.': 19,
#  'ANDREAS ANASTASIOU': 19,
#  'BARNES DEBORAH J': 19,
#  'DATHORNE RONAELE T': 19,
#  'Alastair Matthew Cunningham': 19,
#  'Standard Directors Ltd.': 19,
#  'WILLIAMS CHARLES E.': 19,
#  'JAMES WINGETT HILL': 19,
#  'JUPITER NOMINEES ONE S.A.': 19,
#  'JOHN MICALLEF': 19,
#  'HARPER JOHN CECIL': 19,
#  'ABERDEEN FOUNDATION': 19,
#  'ZHANG HONG': 19,
#  'TRIDENT TRUST COMPANY LIMITED': 19,
#  'ATC SECRETARIAL SERVICES INC.': 19,
#  'Euro-Amex Exchange, Inc.': 19,
#  'Andreas Ellinas': 19,
#  'KINCH GEOFFREY ALLAN': 19,
#  'VICTORY NOMINEES LIMITED': 18,
#  'Bridgewater Second Nominees Limited': 18,
#  'Geoffrey Magistrate': 18,
#  'OLEKSANDR RATSKEVYCH': 18,
#  'WANG HUI': 18,
#  'VITALIY NOVASHCHUK': 18,
#  'CAVERSHAM TRUSTEES LIMITED': 18,
#  'Primi Limited': 18,
#  'Sylvie Erica Hoareau-Cholewinska': 18,
#  'THOMAS BRUCE A': 18,
#  'ATC FOUNDATION': 18,
#  'JOSEPH CASSAR': 18,
#  'Stella G. Port-Louis': 18,
#  'LI LI': 18,
#  'MISCHOSITOS INVESTMENT S.A.': 18,
#  'ZHANG BIN': 18,
#  'AMATUS CAPITAL GROUP LIMITED COMPANY': 18,
#  'Obelisk Nominees Limited': 18,
#  'CUNNINGHAM ALASTAIR MATTHEW': 18,
#  '(BAHAMAS) LTD. CBT': 18,
#  'LOTMORE ROBERT V.': 18,
#  'ANDREW CHARLES WILLIAMS': 18,
#  'WARREN WENDY': 18,
#  'VOLODYMYR OSADCHUK': 18,
#  'PHILLIPS GRENVILLE W.': 18,
#  'EXECUTIVE DIRECTORS (BVI) LTD': 18,
#  'ROCK PETER N.': 18,
#  'Hallmark Management Inc.': 18,
#  'CHANDLER JEFFREY': 18,
#  'SUMNER EDISON L.': 18,
#  'ZHANG JIAN': 18,
#  'BARROLL BROWN MR. JOHN': 18,
#  'Andrew Stuart Moray': 18,
#  'KINGSRIDGE NOMINEES LIMITED': 18,
#  'TRIDENT CORPORATE SERVICES': 18,
#  'APEX NOMINEES 2 LIMITED': 18,
#  'MCLENNAN REX J.': 18,
#  'WANG HAO': 18,
#  'JOHN VELLA': 18,
#  'VERNET EMMANUEL': 18,
#  'CHRYSOSTOM LEODEAN': 18,
#  'BREWER COLIN T. O.': 18,
#  'JONES TONI M.D.': 18,
#  'WANG YING': 18,
#  'LEWIS KEITH L.': 18,
#  'HERMES INTERNATIONAL FOUNDATION': 18,
#  'FITZWILLIAM MICHAEL N.': 18,
#  'WORME ROBERT CHARLES': 18,
#  'IMPERIAL MANAGEMENT SERVICES LTD.': 18,
#  'WARREN TRUSTEES LIMITED': 18,
#  'Trex Limited': 18,
#  'WELFARE RESEARCH FOUNDATION': 18,
#  'Marco A. SAN BERGUIDO': 18,
#  '(BARBADOS) INC. SGG MANAGEMENT': 18,
#  'MARSHALL DALE D.': 18,
#  'Hamilton Trust Company of South Dakota LLC': 18,
#  'LEXINTER INTERNATIONAL INC.': 18,
#  'ALLEYNE IAN A.': 17,
#  'WILLIAMS GRAFTON N.': 17,
#  'KENTISH ELNETH OLIVIER': 17,
#  'BYNOE MICHAEL ROBIN': 17,
#  'ALEKSANDR MANUZOV': 17,
#  'Brock Nominees Limited': 17,
#  'SOROOSH SHAMBAYATI': 17,
#  'MURRELL SHONTELLE N.': 17,
#  'COZIER CARL RICHARD': 17,
#  'GOLLOP FRED WINLYN': 17,
#  'TREDORIC LIMITED': 17,
#  'LI JIAN': 17,
#  'KING GERALD ANTHONY ALLAN': 17,
#  'JOSEPH FENECH': 17,
#  'BLADES DENNIS T.': 17,
#  'DAVIS LARRY A.': 17,
#  'ZHANG YAN': 17,
#  'MARTELLO MANAGEMENT LIMITED': 17,
#  'CARTRUST CORPORATION LIMITED': 17,
#  'MARIO VELLA': 17,
#  'CRAMLINGTON LIMITED': 17,
#  'C.C.S. DIRECTORS LIMITED': 17,
#  'Annabelle Jean-Louis': 17,
#  'Second Court Limited': 17,
#  'ULLYETT MELISSA A.': 17,
#  'MCNEILLY MATTHEW': 17,
#  'HUSBANDS CARLSON E.': 17,
#  'Albert H. Davis': 17,
#  'TONG ROYCE S.': 17,
#  'Maria Christofidou': 17,
#  'ROWE NEVILLE S.': 17,
#  'GITTENS TERRY V.': 17,
#  'EVELYN SUSANNAH M.': 17,
#  'ERNST & YOUNG SERVICES LTD.': 17,
#  'SAGE INVESTMENTS LTD.': 17,
#  'ZENITH NOMINEES LIMITED': 17,
#  'Elaine McGoogan': 17,
#  'HERBERT ARTHUR CHARLES': 17,
#  'ABRAHAMS WILFRED ARTHUR': 17,
#  'HOYOS ELLA N.': 17,
#  'ALLEYNE JOHN RICHARD': 17,
#  'Martha Demetriades': 17,
#  'SMITH NEVILLE L': 17,
#  'BANFIELD RANDALL IAN': 17,
#  'LIMITED COURT ADMINISTRATION': 17,
#  'South Dakota Trust Company LLC': 17,
#  'LIMITED YORKE SECRETARIES': 17,
#  'WANG TAO': 17,
#  'THORNHILL TERRENCE A.': 17,
#  'BAIN SHONALEE': 17,
#  'ALEXANDR ZHUKOV': 17,
#  'FISHER RICHARD A.': 17,
#  'DIEGO JOSE FERNANDEZ KLOSE': 17,
#  'Serangoon Limited': 17,
#  'TATIANA VOZDOVSCAIA': 17,
#  'LUALDI GIUSEPPINA': 17,
#  'GEORGE RAMISHVILI': 17,
#  'MONTAGUE GOLDSMITH INVESTCO ANSTALT': 17,
#  'Bridgewater First Nominees Limited': 17,
#  'CASTLE HILL (NOMINEES) LIMITED': 17,
#  'ALEKSI TOPURIA': 17,
#  'Sean Hogan': 17,
#  'Alexander Studhalter': 17,
#  'HANSCHELL JOHN HOTHER': 17,
#  'HARRIS VIVEK PETER': 17,
#  'The Succession Corporation': 17,
#  'APAKURA LLC.': 17,
#  'ARRINDELL BERNELL L.': 17,
#  'Bearer 6': 16,
#  'Bassim Enterprises Limited': 16,
#  'KNOTT JAMES M.': 16,
#  'FINASWISS FOUNDATION': 16,
#  'JOSEPH AQUILINA': 16,
#  'Dorchester International Inc.': 16,
#  'YANG JUN': 16,
#  'CHRISTIE ADRIAN DEVERE': 16,
#  'C. B. MANAGEMENT LIMITED': 16,
#  'FREESTAR NOMINEES LIMITED': 16,
#  'ECONOMIST INCORPORATED': 16,
#  'PAYNE LEONARD A': 16,
#  'Hophil Nominees (BVI) Limited': 16,
#  'HSBC International Trustee Limited': 16,
#  'JOHN FARRUGIA': 16,
#  'MOSCRIP LIMITED': 16,
#  'GILL STEWART L.': 16,
#  'CHARLES BORG': 16,
#  'WELWYN LIMITED': 16,
#  'WEBER FOUNDATION': 16,
#  'Gaetanne Antat': 16,
#  'SUNION SERVICES CORP.': 16,
#  'ZHANG YI': 16,
#  'DAVID BORGER': 16,
#  'KING MAURICE ADRIAN': 16,
#  'Sean Lee Hogan': 16,
#  'Finistere Limited': 16,
#  'SANTO MANAGEMENT LIMITED': 16,
#  'WHITMILL SECRETARIES LIMITED': 16,
#  'ZHANG JING': 16,
#  'JOSEPH SPITERI': 16,
#  'HARDING DAVID LIONEL': 16,
#  'IDALECIO DE CASTRO RODRIGUES DE OLIVEIRA': 16,
#  'CHACKO JACQUELINE R.': 16,
#  'SERGEY EVSTIFEEV': 16,
#  'WANG PENG': 16,
#  'Andri Athanasiou': 16,
#  'PRICE CLARIS P.J.': 16,
#  'Athnid Limited': 16,
#  'SEYMOUR LAURA JANE HILTON': 16,
#  'EUROSTOCK AG': 16,
#  'LA VILLE SECRETARIES LIMITED': 16,
#  'MAYTREE OVERSEAS S.A.': 16,
#  'Jeffrey Layson': 16,
#  'GILBERT BERNARD': 16,
#  'WILLIAMS SIR CHARLES O.': 16,
#  'A.J.K. WEALTH ADMINISTRAT': 16,
#  'A.J.K. WEALTH MANAGEMENT': 16,
#  'CLARKE ROGER E.E.': 16,
#  'CLEARE ARLENE': 16,
#  'Damor Investments Limited': 16,
#  'JOSEPH BONNICI': 16,
#  'VICTORIA JANE LORAINE': 16,
#  'MARTELLO TRUST COMPANY LIMITED': 16,
#  'TOMLIN WILLIAM': 16,
#  'FINISTERE LIMITED': 16,
#  'JORGE LUIS FELIZ GERMAN': 16,
#  'EUROTRADE DIRECTORS LTD.': 16,
#  'PAUL BORG': 16,
#  'ZHOU XIN': 16,
#  'SIMPSON DEBORAH A.': 16,
#  'bearer': 16,
#  'ESTWICK RICHARD B.': 16,
#  'GRANGE NOMINEES LIMITED': 16,
#  'TOPAZE COMPANY SERVICES S.A.': 16,
#  'Moores Nominees Limited': 16,
#  'SMITH CARLOS': 16,
#  'PAUL CAMILLERI': 16,
#  'CIDEL CORPORATE SERVICES INC.': 16,
#  'CERTIDOR LIMITED': 16,
#  'WALDRON MARLON R.': 16,
#  'C.C.S. CORPORATE SERVICES LIMITED': 16,
#  'ANTHONY GRECH': 16,
#  'QUORUM NOMINEES LIMITED': 16,
#  'WTG MANAGERS LIMITED': 16,
#  'WANG YAN': 16,
#  'SARNIA MANAGEMENT CORP.': 16,
#  'ELIE DOUER': 16,
#  'SCIVIAS TRUST MANAGEMENT LTD.': 16,
#  'JOSEPH VASSALLO': 16,
#  'GCS LTD': 16,
#  ...}

# %%
suspect: dict = {
    name.lower(): count
    for name, count in names.items()
    if count >= 2 and ("bearer" in name.lower() or "portador" in name.lower())
}

suspect
# Out:
# {'the bearer': 4,
#  'el portador': 25,
#  'bearer 1': 13,
#  'bearer': 16,
#  'the  bearer': 114,
#  'bearer 2': 10,
#  'to the bearer': 6,
#  'al portador': 39,
#  'bearer 3': 4,
#  'bearer 4': 5,
#  'bearer 5': 2,
#  'bearer 6': 16,
#  'bearer02': 14,
#  'bearer 8': 14,
#  'bearer 7': 14,
#  'to bearer': 14,
#  'bearer 9': 12,
#  'bearer  - bearer agent - liang chen yuen chi': 10,
#  'bearer 10': 10,
#  'bearer1': 6,
#  'the bearer 50,000 shares': 7,
#  'the bearer at 500 shares': 7,
#  'the bearer (agent: mr. mak kin man)': 7,
#  'bearer share': 5,
#  'the bearer at 50,000 shares': 6,
#  'the bearer of 50,000 shares': 6,
#  'the bearer (agent: pro-corp nominees limited)': 6,
#  'bearer: agent-wirja tanizar': 6,
#  'bearer for immota foundation': 6,
#  'bearer01': 2,
#  'bearer.': 5,
#  'bearer03': 5,
#  'bearer 12': 5,
#  'bearer (elena kyprianou)': 5,
#  'bearer2': 4,
#  'the bearer agent: wbc secretaries ltd.': 4,
#  'the bearer agent: ann lay': 4,
#  'the bearer1': 4,
#  '-the bearer': 4,
#  'bearer 14': 4,
#  'bearer 13': 4,
#  'bearer 15': 4,
#  'bearer10': 4,
#  'bearer 11': 4,
#  'bearer 1-10': 4,
#  'the bearer (50,000)': 4,
#  'the bearer (mr. andrey komarov)': 4,
#  'the bearere': 4,
#  'bearer "a"': 4,
#  'the  bearer (6)': 4,
#  'the bearer:agent davenhill assets limited': 4,
#  'bearer shares': 4,
#  'the bearer (3)': 4,
#  'the bearer (2)': 4,
#  'bearer "b"': 3,
#  'the bearer (mr. yuriy vasilievich schastlivyi)': 3,
#  'the bearer (4)': 3,
#  'the bearer (5)': 3,
#  'the bearer (13)': 3,
#  'the bearer agent-kan pui wai': 3,
#  'bearer 16': 3,
#  'bearer agent: toni juhani salmela': 3,
#  'bearer (vinsonburg management corp.)': 3,
#  'bearer agent:- pro-corp nominees limited': 3,
#  'bearer pro-corp nominees limited': 3,
#  'the bearer (agent pro-corp nominees limited': 3,
#  'the bearer (mr. andrei antonov)': 3,
#  'bearer (agent - mr loh chee yuen)': 3,
#  'bearer 01': 3,
#  'bearer 02': 3,
#  'bearer (christina cornelia van den berg)': 3,
#  'bearer (mr. fuat kurmakaev)': 3,
#  'bearer (josé jaime melendez nuñez)': 3,
#  'bearer11': 3,
#  'bearer warrant': 3,
#  'the bearer agent-pro-corp nominees limited': 3,
#  'thebearer': 3,
#  'the bearer (mr. roman guilmanov)': 3,
#  'teh bearer': 3,
#  'hte bearer': 3,
#  'bearer3': 3,
#  'bearer4': 3,
#  'bearer04': 3,
#  'the bearer.': 3,
#  'the bearer (mr. paul speck)': 3,
#  'the bearer agent; chong lai chak': 2,
#  'the bearer (mr. stanislav maltsev)': 2,
#  'the bearer (agent: shum wing chuen)': 2,
#  'the bearer agent chan hon pun': 2,
#  'the bearer (holder the beresford group)': 2,
#  'the bearer - holder the beresford group': 2,
#  'the bearer (in favour of mr. stanislav obolentsev)': 2,
#  'bearer - b': 2,
#  'bearer - a': 2,
#  'bearer no. 2': 2,
#  'bearer no. 1': 2,
#  'bearer (mr. alexander anatolievich fedorov)': 2,
#  'the bearer agent:- pro corp nominees limited': 2,
#  'bearer (valcos limited)': 2,
#  'bearer (mr. komiljon boborajabov)': 2,
#  'the bearer ( mr. anvar jaxybergenov)': 2,
#  'the bearer:-pro-corp nominees limited': 2,
#  'the bearer (mr.evgeny semenov)': 2,
#  'bearer (agent: mr. dang thanh phong)': 2,
#  'bearer a': 2,
#  'bearer b': 2,
#  'bearer07': 2,
#  'bearer06': 2,
#  'bearer08': 2,
#  'bearer05': 2,
#  'the bearer agent: pro-cop nominees limited': 2,
#  'bearer09': 2,
#  'bearer (lim kaling)': 2,
#  'the bearer agent: pro-corp nominees limited': 2,
#  'the bearer (20)': 2,
#  'the bearer (10)': 2,
#  'the bearer (15)': 2,
#  'the bearer (18)': 2,
#  'the bearer (14)': 2,
#  'the bearer (16)': 2,
#  'the bearer (lost)': 2,
#  'bearer (sandra lucia thomas)': 2,
#  'bearer (reedeem shares)': 2,
#  'bearer - havelet trust company (bvi) limited': 2,
#  'bearer (chao tsan)': 2,
#  'bearer(emerald tracking corp)': 2,
#  'bearer(lisina properties inc)': 2,
#  'tthe bearer': 2,
#  'the bearer agent: chu chuck ling and lo yim wah': 2,
#  'bearer (when the company was existing in niue)': 2,
#  'bearer (received by leung wai cheong)': 2,
#  'the bearer (agent: mr. rene josef hodel)': 2,
#  'the bearer (agent: rene josef hodel)': 2,
#  'the bearer (7)': 2,
#  'the bearer (8)': 2,
#  'the bearer (9)': 2,
#  'the bearer (11)': 2,
#  'the bearer (12)': 2,
#  'bearer-bearer agent-fiscal corporate services sdn bhd': 2,
#  'the bearer at 2,500': 2,
#  'bearer shareholder': 2,
#  'the, bearer': 2,
#  'bearer  c/o anwar wagdy mohamed metwally mobasher': 2,
#  'bearer (to c/o casitalinda ltd.': 2,
#  'the bearer2': 2,
#  "bearer c/o m'exim international ltd": 2}

# %%
len(suspect)
# Out:
# 146

# %% [markdown]
# Identify regex patterns to use for filtering these legalese placeholders.

# %%
import re

PAT_LIST: list = [
    r"^\-?(to\s+)?([the]+\s+)?bearer\.?\s?(\d+)?(\w)?$",
    r"^.*bearer.*shares?$",
    r"^the\s+bearer\s+\([\d\,]+\)$",
    r"^[ae]l\s+portador$",
    r"^the\s?bearer$",
    r"^bearer\s?warrant$",
    r"^bearer\s?shareholder$",
    r"^the\,\s+bearer$",
    r"^bearer\s+\(reedeem\s+shares\)$",
    r"^the\s+bearer\s+\(lost\)$",
    r"^bearer\s+\-\s+[\w]$",
    r"^bearer\s+\"\w\"$",
    r"^bearer\s+[\d\-]+$",
    r"^bearer\s+no\.\s+\d+$",
    r"^the\s+bearer\s+at\s+[\d\,]+$",
    r"^nan$",
    r"^[\?]+$",
]

def filter_bearer (
    name: str,
    ) -> bool:
    name = name.lower()

    for pat in PAT_LIST:
        if re.search(pat, name) is not None:
            return False

    return True

total: int = 0

for name, count in suspect.items():
    if filter_bearer(name):
        ic(name, count)
        total += 1

total
# Out:
# ic| name: 'bearer  - bearer agent - liang chen yuen chi', count: 10
# ic| name: 'the bearer (agent: mr. mak kin man)', count: 7
# ic| name: 'the bearer (agent: pro-corp nominees limited)', count: 6
# ic| name: 'bearer: agent-wirja tanizar', count: 6
# ic| name: 'bearer for immota foundation', count: 6
# ic| name: 'bearer (elena kyprianou)', count: 5
# ic| name: 'the bearer agent: wbc secretaries ltd.', count: 4
# ic| name: 'the bearer agent: ann lay', count: 4
# ic| name: 'the bearer (mr. andrey komarov)', count: 4
# ic| name: 'the bearer:agent davenhill assets limited', count: 4
# ic| name: 'the bearer (mr. yuriy vasilievich schastlivyi)', count: 3
# ic| name: 'the bearer agent-kan pui wai', count: 3
# ic| name: 'bearer agent: toni juhani salmela', count: 3
# ic| name: 'bearer (vinsonburg management corp.)', count: 3
# ic| name: 'bearer agent:- pro-corp nominees limited', count: 3
# ic| name: 'bearer pro-corp nominees limited', count: 3
# ic| name: 'the bearer (agent pro-corp nominees limited', count: 3
# ic| name: 'the bearer (mr. andrei antonov)', count: 3
# ic| name: 'bearer (agent - mr loh chee yuen)', count: 3
# ic| name: 'bearer (christina cornelia van den berg)', count: 3
# ic| name: 'bearer (mr. fuat kurmakaev)', count: 3
# ic| name: 'bearer (josé jaime melendez nuñez)', count: 3
# ic| name: 'the bearer agent-pro-corp nominees limited', count: 3
# ic| name: 'the bearer (mr. roman guilmanov)', count: 3
# ic| name: 'the bearer (mr. paul speck)', count: 3
# ic| name: 'the bearer agent; chong lai chak', count: 2
# ic| name: 'the bearer (mr. stanislav maltsev)', count: 2
# ic| name: 'the bearer (agent: shum wing chuen)', count: 2
# ic| name: 'the bearer agent chan hon pun', count: 2
# ic| name: 'the bearer (holder the beresford group)', count: 2
# ic| name: 'the bearer - holder the beresford group', count: 2
# ic| name: 'the bearer (in favour of mr. stanislav obolentsev)'
#     count: 2
# ic| name: 'bearer (mr. alexander anatolievich fedorov)', count: 2
# ic| name: 'the bearer agent:- pro corp nominees limited', count: 2
# ic| name: 'bearer (valcos limited)', count: 2
# ic| name: 'bearer (mr. komiljon boborajabov)', count: 2
# ic| name: 'the bearer ( mr. anvar jaxybergenov)', count: 2
# ic| name: 'the bearer:-pro-corp nominees limited', count: 2
# ic| name: 'the bearer (mr.evgeny semenov)', count: 2
# ic| name: 'bearer (agent: mr. dang thanh phong)', count: 2
# ic| name: 'the bearer agent: pro-cop nominees limited', count: 2
# ic| name: 'bearer (lim kaling)', count: 2
# ic| name: 'the bearer agent: pro-corp nominees limited', count: 2
# ic| name: 'bearer (sandra lucia thomas)', count: 2
# ic| name: 'bearer - havelet trust company (bvi) limited', count: 2
# ic| name: 'bearer (chao tsan)', count: 2
# ic| name: 'bearer(emerald tracking corp)', count: 2
# ic| name: 'bearer(lisina properties inc)', count: 2
# ic| name: 'the bearer agent: chu chuck ling and lo yim wah', count: 2
# ic| name: 'bearer (when the company was existing in niue)', count: 2
# ic| name: 'bearer (received by leung wai cheong)', count: 2
# ic| name: 'the bearer (agent: mr. rene josef hodel)', count: 2
# ic| name: 'the bearer (agent: rene josef hodel)', count: 2
# ic| name: 'bearer-bearer agent-fiscal corporate services sdn bhd'
#     count: 2
# ic| name: 'bearer  c/o anwar wagdy mohamed metwally mobasher'
#     count: 2
# ic| name: 'bearer (to c/o casitalinda ltd.', count: 2
# ic| name: "bearer c/o m'exim international ltd", count: 2
# 57

# %% [markdown]
# Confirm whether this filter works…

# %%
counter: Counter = Counter()

for name, count in df["name"].value_counts().to_dict().items():
    if filter_bearer(name):
        counter[name] += count

counter.most_common(1000)
# Out:
# [('CARMICHAEL TREVOR A.', 1196),
#  ('CLEMENTI LIMITED', 1111),
#  ('TANAH MERAH LIMITED', 1046),
#  ('BUKIT MERAH LIMITED', 963),
#  ('CST ADMINISTRATION (BAHAM', 835),
#  ('THE CORPORATE SECRETARY LIMITED', 700),
#  ('Christopher Marcus GRADEL', 576),
#  ('COURT ADMINISTRATION LIMI', 474),
#  ('PRIMARY MANAGEMENT LIMITE', 449),
#  ('BARNES DEBORAH J.', 416),
#  ('FIELDS JAMES A.', 408),
#  ('BLUE SEAS ADMINISTRATION', 389),
#  ('STANDARD NOMINEES (BAHAMA', 384),
#  ("TRIDENT CORPORATE SERVICES (B'DOS) LTD", 369),
#  ('CIRCLE CORPORATE SERVICES', 343),
#  ('CORPORATE SERVICES LIMITED', 319),
#  ('GUARDIAN NOMINEES (BARBADOS) LIMITED', 288),
#  ('IL SHIN CORPORATE CONSULTING LIMITED', 286),
#  ('KHAN ZARINA', 283),
#  ('CASCADO AG', 275),
#  ('OCTAGON MANAGEMENT LIMITE', 272),
#  ('Vanessa Marie-Antoine PAYET', 259),
#  ('AMICORP (BARBADOS) LTD.', 243),
#  ('Shirley Sabia Therese VAN KERKHOVE', 242),
#  ('MANEX LIMITED', 238),
#  ('BDG MANAGEMENT LTD.', 231),
#  ('SISNETT NATALIA B.', 230),
#  ('WORME ROBERT C.', 220),
#  ('CALLAGHAN DAVID F.', 219),
#  ('COLYBRAND COMPANY SERVICES LIMITED', 216),
#  ('C.B. MANAGEMENT LTD.', 215),
#  ('C.B. STRATEGY LTD.', 213),
#  ('International Administrators Limited', 211),
#  ('TRUSS ARON DAVID', 209),
#  ('Nominees One Limited', 206),
#  ('Nominees Two Limited', 204),
#  ('BOURQUE MARY ELLEN M.', 202),
#  ('Songbird Limited', 202),
#  ('ERASMUS MANAGEMENT LTD.', 193),
#  ("AMICORP CORPORATE SERVICES (B'DOS) LTD", 184),
#  ('FERREIRA ANDREW C.', 178),
#  ('OSWALDO JESUS CISNEROS FAJARDO', 174),
#  ('CARMICHAEL TREVOR A', 174),
#  ('CHAPMAN STANLEY K.', 172),
#  ('SKINNER CHRISTOPHER H.', 172),
#  ('LA FALAISE MANAGEMENT LTD', 171),
#  ('GTC MANAGEMENT LTD.', 169),
#  ('Genevieve Odette Rona MAGNAN', 168),
#  ('NOMARK LIMITED', 166),
#  ('PRISM MANAGEMENT LIMITED', 164),
#  ('SERVICES (BARBADOS) LTD. TRIDENT CORPORATE', 161),
#  ('BSI MANAGEMENT LTD.', 159),
#  ('Minor*', 159),
#  ('KING DAVID N.', 157),
#  ('Neesha Lynn KUMAR', 148),
#  ('HARRIDYAL-SODHA LIZA A.', 147),
#  ('PATEL MOHAMMED E.', 147),
#  ('TARPUMBAY LIMITED', 145),
#  ('BARATERRE LIMITED', 145),
#  ('DIRMAC LIMITED', 144),
#  ('DIZAME CONSULTING SA', 143),
#  ('DILIGENTIA LTD.', 142),
#  ('PATTERSON PETER MCG.', 138),
#  ('MANEX LTD.', 133),
#  ('MEDITERRANEAN MANAGEMENT', 128),
#  ('CARICORP (BARBADOS) INC.', 126),
#  ('REPULSE BAY LIMITED', 121),
#  ('GREAVES STEPHEN L.', 118),
#  ('CREDIT SUISSE TRUST LIMIT', 114),
#  ('THORNHILL ANDREW V.', 113),
#  ('SILVERSTRAND BAY LIMITED', 113),
#  ('DGM TRUST CORPORATION', 111),
#  ('GENEVIEVE ODETTE RONA MAGNAN', 110),
#  ('SHIRLEY SABIA THERESE VAN KERKHOVE', 108),
#  ('BOURQUE ROBERT J.', 108),
#  ('GITTENS THEODORE DAVID', 108),
#  ('STAGRINTIE LIMITED', 107),
#  ('RINTIEGAST LIMITED', 107),
#  ('STEVMAR CORPORATE SERVICES LTD.', 106),
#  ('PARKER STEVEN K.', 106),
#  ('BETHEL OWEN', 106),
#  ('TRIANGLE ADMINISTRATION L', 106),
#  ('THOMPSON JOAN L.', 105),
#  ('MONNARD PIERRE', 103),
#  ('MAHABIR MARY J.', 103),
#  ('SUMNER EDISON', 101),
#  ('SKINNER BARRY M.', 101),
#  ('CBT (BAHAMAS) LTD.', 101),
#  ('Christodoulus G. Vassiliades & Co. LLC', 99),
#  ('CORPORATE MANAGERS (BARBADOS) LTD.', 96),
#  ('MARAJ RAMNATH H.', 96),
#  ('DUNN GRAHAM J.', 96),
#  ('GOSSELIN GILLES L.', 96),
#  ('CLARKE MILLICENT', 95),
#  ('DIZAME CONSULTING S.A.', 93),
#  ('THOMSON KENNETH F.G.', 93),
#  ('HOERKENS KARL', 92),
#  ('CHARITABLE AND GOODWILL FOUNDATION', 92),
#  ('NORTH ATLANTIC SERVICES LIMITED', 91),
#  ('TRUST COMPANY OF BARBADOS LIMITED', 89),
#  ('SMS LTD.', 89),
#  ('THOMPSON TYSON W.', 88),
#  ('GESTAM ADMINISTRATION LTD', 88),
#  ('Alexandra MARANDEL', 87),
#  ('CHANCERY CORPORATE SERVICES LIMITED', 87),
#  ('GODET CONSTANCE', 86),
#  ('APAKURA LLC', 86),
#  ('CSUMRIK DAVID G.', 86),
#  ('STERLING EAST LTD.', 84),
#  ('LAWRENCE JOHN M.', 82),
#  ('KNOWLES SONYA NICOLE', 82),
#  ('WEBBER ANGELA R.', 81),
#  ('SECRETARY LIMITED THE CORPORATE', 80),
#  ('LUCAYA MANAGEMENT NOMINEE', 80),
#  ('FORMIA LIMITED', 77),
#  ('TRIDENT CORPORATE SERVICE (BARBADOS) LIMITED', 77),
#  ('YEVGENIY FELD', 77),
#  ('THOMPSON KATHY-ANN R-A.', 77),
#  ('BAYSHORE DIRECTORS INC.', 77),
#  ('FIRST COURT LIMITED', 76),
#  ('GITTENS THEODORE D.', 76),
#  ('MAYO NOMINEES LIMITED', 76),
#  ('ASKAR ALSHINBAYEV', 75),
#  ('PRIME MANAGEMENT SERVICES LIMITED', 75),
#  ('WEEKES RYLE L.', 75),
#  ('GODDARD COLIN G.', 74),
#  ('BRATHWAITE ADRIEL D.', 74),
#  ('ERASMUS MANAGEMENT LTD', 74),
#  ('MAYO SECRETARIES LIMITED', 73),
#  ('SERVICES (BARBADOS) LTD. AMICORP CORPORATE', 72),
#  ('BOOS PETER N.', 72),
#  ('FITZWILLIAM MICHAEL NEIL', 72),
#  ('COLLINS MICHAEL', 72),
#  ('Angela On Kei LEONG', 72),
#  ('CLIFFORD WARREN', 72),
#  ('DOUGLAS WILLIAM P.A.', 72),
#  ('MONTAGUE EAST LTD.', 71),
#  ('JONES SHIRELLE', 70),
#  ('DE POURTALES PAUL', 70),
#  ('GOSSET MANAGEMENT LTD', 69),
#  ('Sylvie CHOLEWINSKA', 68),
#  ('Jennifer GONTIER', 67),
#  ('CRISTINA STUART GREEN', 67),
#  ('EVELYN PETER R.P.', 67),
#  ('VANESSA MARIE-ANTOINE PAYET', 66),
#  ('RICHMOND NOMINEES LIMITED', 66),
#  ('Company Kit Nominees Inc.', 66),
#  ('GARDINER STUART JAMES', 65),
#  ('CORPORATE SERVICES LTD. EIGHTH AVENUE', 65),
#  ('BUKIT TANAH LIMITED', 64),
#  ('CARTER PATRICIA HEATHER', 64),
#  ('PEAT MARWICK ASSOCIATES LIMITED', 64),
#  ('CHARLOTTE MANAGEMENT LTD', 64),
#  ('Christopher Marcus Gradel', 63),
#  ('', 63),
#  ('(BARBADOS) LIMITED GUARDIAN NOMINEES', 62),
#  ('TRIDENT CORPORATE SERVICE S (BARBADOS) LIMITED', 62),
#  ('ALTMAN PAUL B.', 62),
#  ('SMITH DAVID', 61),
#  ('WARD JOSEPH W.', 60),
#  ('FIELDS WAYNE I.', 60),
#  ('DOUGLAS WILLIAM PETER A.', 60),
#  ('AMICORP (BARBADOS) LTD', 58),
#  ('Sylvie Erica HOAREAU-CHOLEWINSKA', 58),
#  ('WILLIAMS RALPH S. DEC.', 58),
#  ('BRUSSELS MANAGEMENT LTD.', 58),
#  ('GAIRNS LTD.', 58),
#  ('HANSCHELL CAROL', 58),
#  ('DOUGLAS WILLIAM P. A.', 57),
#  ('BOSFIELD NATHANIEL F.', 57),
#  ('MEYER EDWARD A.', 57),
#  ('MAYERS JOHN M.', 56),
#  ('SECOND COURT LIMITED', 56),
#  ('CAVERSHAM NOMINEES LIMITED', 56),
#  ('BANNISTER YOLANDE A.L.', 55),
#  ('NURZHAN SUBKHANBERDIN', 54),
#  ('PAYNE LEONARD A.', 54),
#  ('HIGHLAND RYAN A.', 54),
#  ('BROCK NOMINEES LIMITED', 54),
#  ('(BAHAMAS) LIMITED CST ADMINISTRATION', 53),
#  ('MOHUL NOMINEES LIMITED', 53),
#  ('LIMITED SECOND DIRECTORSHIPS', 53),
#  ('TENBY NOMINEES LIMITED', 53),
#  ('TOWNER CHRISTOPHER J.N.', 53),
#  ('KASTEL LIMITED', 53),
#  ('WILLIAMS CHARLES O.', 53),
#  ('LEACH SHARON L.', 52),
#  ('INTERCON LIMITED', 52),
#  ('ALTUS LIMITED', 52),
#  ('LIMITED FIRST DIRECTORSHIPS', 52),
#  ('CAVERSHAM SECRETARIES LIMITED', 52),
#  ('THORNHILL ANDREW VANROY', 52),
#  ('LIVINGSTON GROUP S.A.', 51),
#  ('AMICORP (BAHAMAS) LTD.', 51),
#  ('BJERKHAMN BJORN F.', 51),
#  ('JOSEPH VELLA', 51),
#  ('BSI ADMINISTRATION LTD.', 51),
#  ('HILLARD ENTERPRISES S.A.', 50),
#  ('CLARKE GILLIAN M.H.', 50),
#  ('TAGGART JULIA A.', 50),
#  ('MINERVA NOMINEES LIMITED', 50),
#  ('STANGUARD NOMINEES (BARBADOS) LIMITED', 50),
#  ('GIBBS TONY', 49),
#  ('Xin ZHOU', 49),
#  ('EMTAGE STEPHEN E.', 49),
#  ('SMITH NEVILLE L.', 49),
#  ('WEETCH MICHAEL J.', 49),
#  ('CHANDLER DENNIS H.L.', 49),
#  ('HARRIDYAL-SODHA LIZA A', 49),
#  ('BOYCE MICHAEL R.', 49),
#  ('SMITH JENNIFER G.', 48),
#  ('Harris Worldwide Ltd', 48),
#  ('HAMILTON NOMINEES LIMITED', 48),
#  ('BRATHWAITE VERE P.', 48),
#  ('MCCLURG HAMISH G.', 48),
#  ('JOSEPH CAMILLERI', 48),
#  ('JOSEPH ZAMMIT', 48),
#  ('MSI NOMINEES LTD.', 48),
#  ('FARMER STEPHEN W.', 48),
#  ('BSI TRUST CORPORATION (BA', 47),
#  ('WORRELL LEODEAN', 47),
#  ('DE LADURANTAYE ANDRE', 47),
#  ('MARSHALL DALE DERMONT', 47),
#  ('JOSEPH BORG', 47),
#  ("IBC'S SERVICES INCORPORATED", 47),
#  ('NAGAI TREVOR P.', 47),
#  ('SERVICES LIMITED CHANCERY CORPORATE', 46),
#  ('WALFORD PETER A.', 46),
#  ('Olavinlinna Invest Oy', 46),
#  ('BEATUS LIMITED', 46),
#  ('JOSEPH FARRUGIA', 46),
#  ('THE BAERER', 46),
#  ('GEORGIOS DEMATHAS', 46),
#  ('Suomenlinna Inter Oy', 46),
#  ('ABG SECRETARY INC.', 45),
#  ('BROTHERHOOD FOUNDATION', 45),
#  ('FIELDS ALLAN CLIFFORD', 45),
#  ('BISHOP IAN C.A.', 45),
#  ('THRONEBURY ARLENE', 45),
#  ('Shirley Sabia Therese Van Kerkhove', 45),
#  ('TRIANON INCORPORATED', 45),
#  ('EIGHTH AVENUE CORPORATE SERVICES LTD.', 45),
#  ('SEALY RUPERT B.', 45),
#  ('ELCAN NOMINEES LIMITED', 44),
#  ('CANNON NOMINEES LIMITED', 44),
#  ('METANI DIRECTION LIMITED', 44),
#  ('CAVERSHAM HOLDINGS LIMITED', 43),
#  ('REID ROBERT J.', 43),
#  ('HAMILTON TRUSTEES LIMITED', 43),
#  ('Jennifer Anne GONTIER', 43),
#  ('Trident Trust Company (South Dakota) Inc', 43),
#  ('INDER RIEDEN ANTHONY L.M.', 43),
#  ('Matthew Charles Stokes', 43),
#  ('HAMPDEN VINSTON E.', 43),
#  ('CANNON INTERNATIONAL LIMITED', 43),
#  ('INVESTA MANAGEMENT LIMITED', 43),
#  ('KNIGHT RICARDO O.', 42),
#  ('Bolsdoto Holdings Limited', 42),
#  ('GOLD LION DIRECTOR SERVICES INC.', 42),
#  ('PATEL MOHAMMED E', 42),
#  ('Marie Alexandra Sherlaine MARANDEL', 42),
#  ('NAUTILUS NOMINEE SERVICES LIMITED', 41),
#  ('Management Group Limited', 41),
#  ('MINERVA SERVICES LIMITED', 41),
#  ('MOSSFON NOMINEES LIMITED', 41),
#  ('IPCO S.A.', 41),
#  ('CORPORATE MANAGERS (BARBADOS) LTD', 41),
#  ('NELEX FINANCE SA', 41),
#  ('WRIGHT DAVID O.', 41),
#  ('L.G. SECRETARIES LIMITED', 40),
#  ('HARRIS PETER V.', 40),
#  ('WORKMAN JOAN Y.', 40),
#  ('JOSE RICARDO POMA DELGADO', 40),
#  ('Jesse Grant Hester', 40),
#  ('CARIBBEAN CORPORATE SERVICES LTD.', 40),
#  ('KONSTANTIN GRIGORISHIN', 40),
#  ('SELETAR LIMITED', 40),
#  ('HOLOWESKO LYNN P.', 39),
#  ('SMITH CECIL A.B.', 39),
#  ('ELLIS ANTHONY G.', 39),
#  ('THOMAS BRUCE A.', 39),
#  ('Ferdo A. Gil', 39),
#  ('PRIMI LIMITED', 39),
#  ('CARMICHAEL TREVOR AUSTIN', 38),
#  ('JUMAN AZAZ KHAN', 38),
#  ('JOHNSON RALPH L.', 38),
#  ('GCS LTD.', 38),
#  ('SCTS Capital Pte. Ltd', 38),
#  ('Rodney Reddy MARENGO', 38),
#  ('FIDELIS NOMINEES LIMITED', 38),
#  ('KING DAVID N', 38),
#  ('BYNOE CHRISTOPHER DAVID', 38),
#  ('MARSHALL ANTHONY RICHARD S.', 37),
#  ('EVANS CHRISTOPHER G.', 37),
#  ('Baraterre Limited', 37),
#  ('PARKER STEVEN K', 37),
#  ('MAXWELL LIMITED', 37),
#  ('CHELSTON DIRECTOR SERVICES INC.', 37),
#  ('CRUIKSHANK ALLAN B.', 36),
#  ('BTT Nominees (BVI) Ltd (ex ING Nominees (BVI) Ltd.', 36),
#  ('WORO LTD.', 36),
#  ('DAVIES DAWN E.', 36),
#  ('BANNISTER YOLANDE A. L.', 36),
#  ('ANA GIANNINA FASANELLI CAVALLAZZI', 36),
#  ('PERREIRA KAREN ANN', 36),
#  ('Stephen John Kelly', 36),
#  ('Minerva Nominees Limited', 36),
#  ('Integrity Directors Ltd', 36),
#  ('METZGER JOHN H.', 35),
#  ('COMPANY KIT NOMINEES INC.', 35),
#  ('RICARDO JOSE CISNEROS RENDILES', 35),
#  ('Tarpumbay Limited', 35),
#  ('GEOFFREY MAGISTRATE', 35),
#  ('MEYER EDWARD ADRIAN', 35),
#  ('BOS NOMINEES (JERSEY) LIMITED', 35),
#  ('TEMPRO PHILIP G.', 35),
#  ('FORBES HELEN A.', 35),
#  ('JOSEPH MICALLEF', 35),
#  ('DOTTIN MAUREEN ELIZABETH', 35),
#  ('Victor Joseph Vandewater', 35),
#  ('MS. LEONG ANGELA ON KEI', 35),
#  ('SOCIEDAD DE DIRECTORIA CE', 35),
#  ('C B MANAGEMENT LTD.', 35),
#  ('C B STRATEGY LTD.', 35),
#  ('BASTIAN ANTOINE', 35),
#  ('Raul Garrido Garibaldo', 35),
#  ('THOMPSON TYSON W', 35),
#  ('LIMITED WELWYN', 35),
#  ('BESTER DAVID HERMANUS', 34),
#  ('NAUTILUS CORPORATE SERVICES LIMITED', 34),
#  ('BUKTI TANAH LIMITED', 34),
#  ('FERREIRA ANDREW C', 34),
#  ('CLARKE HAZEL PAMELA', 34),
#  ('SCTS Management Pte. Ltd', 34),
#  ('Eurotrade Nominees Ltd.', 34),
#  ('JONES JOHN-PAUL', 34),
#  ('Joseph Sparks', 34),
#  ('PILE AMANDA J.', 34),
#  ('IMPERIAL MANAGEMENT SERVICES LTD', 34),
#  ('BOS SECRETARIES (JERSEY) LIMITED', 33),
#  ('WORD LTD.', 33),
#  ('FENCHURCH TRUST LIMITED', 33),
#  ('Bernard Loh See Fun', 33),
#  ('Si Bodmer', 33),
#  ('UNICO LIMITED', 33),
#  ('GREAVES STEPHEN L', 33),
#  ('Genevieve Odette Rona Mag', 33),
#  ('Ferdo A. GIL', 33),
#  ('OFFSHORE SOLUTIONS INC.', 33),
#  ('COZIER FRANCIS S.', 32),
#  ('THOMSON KENNETH F. G.', 32),
#  ('CARMICHAEL* TREVOR A.', 32),
#  ('Un Chan CHAN', 32),
#  ('ZHANG WEI', 32),
#  ('MTB Clients Nominees Limited', 32),
#  ('HARPO S.A.', 32),
#  ('SERANGOON LIMITED', 32),
#  ('LASHLEY AMANDA J.', 32),
#  ('STICHTING SALISBURY', 32),
#  ('THE CORPORATE SECRETARY* LIMITED', 32),
#  ('HORNBEAM CORP.', 32),
#  ('HOYOS ANTHONY C.', 32),
#  ('SMS LTD', 32),
#  ('ABDULLAH AL SHARIF AL HUSSEIN', 32),
#  ('VLADIMIR CHERNUKHIN', 32),
#  ('SKINNER CHRISTOPHER H', 32),
#  ('ACTON FINANCIAL SERVICES LIMITED', 32),
#  ('MILLINGTON DAVID A.', 32),
#  ('JOSEPH GALEA', 31),
#  ('JONES RONALD W.', 31),
#  ('MURRAY COLIN D.', 31),
#  ('MFM FOUNDATION', 31),
#  ('BLACKMAN CHRISTOPHER A.', 31),
#  ('CORPORATE SERVICES* LIMITED', 31),
#  ('BOYNE LIMITED', 31),
#  ('DELANY DUSTIN D.P.', 31),
#  ('PINE GROVE FOUNDATION', 31),
#  ('COLE HAROLD L.', 31),
#  ('Cannon Nominees Limited', 31),
#  ('NOMIHOLD SECURITIES INC.', 31),
#  ('SERRAO PHILIP EVAN', 31),
#  ('FAIR IAN D.', 31),
#  ('ORION NOMINEES LIMITED', 31),
#  ('COURT ADMINISTRATION LTD.', 31),
#  ('Formia Limited', 31),
#  ('REFAEL EDRY', 31),
#  ('ADMINISTRA INC.', 31),
#  ('HALOUTE ELIAS', 31),
#  ('BUSINESS MANAGEMENT LIMIT', 31),
#  ('Minerva Services Limited', 30),
#  ('MAHABIR MARY J', 30),
#  ('PENSHORE EQUITIES CORP.', 30),
#  ('MANSOUR ABDELMEGEED MANSOUR AMER', 30),
#  ('FROST FRANCES ALISON', 30),
#  ('MCKAY ANDREW A.', 30),
#  ('Barbara Chatterton', 30),
#  ('TINDALE DAVID', 30),
#  ('BLACKETT SHERENE N.', 30),
#  ('AMICORP CORPORATE SERVICE (BARBADOS) LTD.', 30),
#  ('INNISS DONVILLE O.', 30),
#  ('BANKHILL LIMITED', 30),
#  ('KHAN MOHAMED H.', 30),
#  ('FIELDS THEROLD O`N', 30),
#  ('Herna Rita CHARLES', 30),
#  ('UCE SECRETARIES S.A.', 30),
#  ('SISNETT NATALIA B', 30),
#  ('Cannon International Limited', 30),
#  ('GALE BARRY LOUIS VALENCE', 30),
#  ('CBT SECRETARIAL SERVICES', 30),
#  ('MS. STELLA G. PORT-LOUIS', 30),
#  ('TOMLIN WILLIAM M.', 30),
#  ('Thomas Chatterton', 29),
#  ('DAMOR INVESTMENTS LIMITED', 29),
#  ('JAIME GILINSKI BACAL', 29),
#  ('GALE BARRY L.V.', 29),
#  ('THE GENERAL FIDUCIARY COMPANY LIMITED', 29),
#  ('MOORES NOMINEES LIMITED', 29),
#  ('LED SERVICES ESTABLISHMENT', 29),
#  ('WALCOTT STEPHEN JOHN', 29),
#  ('TREX LIMITED', 29),
#  ('GONSALVES LESLIE T.', 29),
#  ('NICHOLLS PHILIP V.', 29),
#  ('CLARKE ALFRED H.', 29),
#  ('GODDARD JOSEPH N.', 29),
#  ('THANI ABDULLA T.J. AL THANI', 29),
#  ('BREWER COLIN T.O.', 29),
#  ('NORMAN BENITO FIORE', 28),
#  ('CLARKE BRIAN H.', 28),
#  ('GEORGIOS KANTAS', 28),
#  ('MOSSFON SUBSCRIBERS LTD.', 28),
#  ('HEWITT KENNETH R.', 28),
#  ('BYNOE CHRISTOPHER D.', 28),
#  ('CRICHLOW NICHOLAS C.', 28),
#  ('SOCIEDAD LATINA DE MANAGE', 28),
#  ('BRATHWAITE ADRIEL D', 28),
#  ('WILLIAMS CLYDE Q.', 28),
#  ('WEBSTER DELIA', 28),
#  ('CAFFERATA JEREMY A.C.', 28),
#  ('MARIA DEL PILAR AROSEMENA DE ALEMAN', 28),
#  ('JONES MELANIE S.', 28),
#  ('OLGA BOGOMAZOVA', 28),
#  ('FARMER STEPHEN WILFRED', 28),
#  ('MIKAIL GUTSERIEV', 28),
#  ('SMITH NEVILLE LEROY', 28),
#  ('SKINNER BARRY M', 28),
#  ('BASEL ONE LIMITED', 28),
#  ('PETER JOHN GOULANDRIS', 28),
#  ('INTERCON NOMINEES LIMITED', 28),
#  ('NORTHQUAY LIMITED', 28),
#  ('COURT ADMINISTRATION', 27),
#  ('DELANY DUSTIN DAVID PHILLA', 27),
#  ('SARNIA MANAGEMENT LTD.', 27),
#  ('Denys Meade Laurence', 27),
#  ('FALCON NOMINEES LIMITED', 27),
#  ('TRAFALGAR NOMINEES LIMITED', 27),
#  ('CORPORATE NOMINEES LIMITED', 27),
#  ('CACIQUE INVESTMENTS LIMITED', 27),
#  ('WAI FUNG CHEUNG', 27),
#  ('YAHYA NADIA A.', 27),
#  ('JOSEPH MUSCAT', 27),
#  ('MIKAIL SHISHKHANOV', 27),
#  ('DELMAS FRERE FRANCIS C.', 27),
#  ('CAVE RONALD GEOFFREY', 27),
#  ('WANG WEI', 27),
#  ('BOURQUE ROBERT J', 27),
#  ('YOUNG PHILIP S.', 27),
#  ('WILLIAMS JOHN M.B.', 27),
#  ('Silver Zone Management Inc.', 27),
#  ("Raymond O'Reilly", 27),
#  ('MEINIG WALTER P.', 27),
#  ('Vanessa Marie-Antoine Payet', 27),
#  ('SZE HOI KWAI', 27),
#  ('GOODING ROGER D.', 27),
#  ('CHEN WEI', 27),
#  ('ROLIKA INC.', 27),
#  ('Stratford Management Ltd', 27),
#  ('WEATHERHEAD BERNARD ANTHONY', 27),
#  ('JOSHUA CARL BELL', 26),
#  ('American Corporate Services, Inc. (USA)', 26),
#  ('DANIEL DEREK L.', 26),
#  ('ROSENBLOOM ALLAN', 26),
#  ('STEINBOK JOSEPH', 26),
#  ('DEFREITAS PETER E.', 26),
#  ('HANCOCK STEPHEN', 26),
#  ('BOS Secretaries (Jersey) Limited', 26),
#  ('BDG MANAGEMENT LTD', 26),
#  ('BENEFICENCE FOUNDATION', 26),
#  ('JOHN BORG', 26),
#  ('TOPPIN PATRICK B.', 26),
#  ("BAYSHORE CORPORATE SERVICES (B'DOS) LTD", 26),
#  ('NWT NOMINEES LIMITED', 26),
#  ('BRATHWAITE JONATHAN J.K.', 26),
#  ('MCEVOY DAVID I.', 26),
#  ('ODLE PETER JULIAN', 26),
#  ('ATC ADMINISTRATORS INC.', 26),
#  ('GALIMZHAN YESSENOV', 26),
#  ('KHAN MOHAMED HAFIZ', 26),
#  ('DGM BANK & TRUST INC.', 26),
#  ('PATEL NAEEM A. E.', 26),
#  ('MAYFAIR NOMINEES LIMITED', 26),
#  ('SERGEY ALEXANDROVICH PUGACHEV', 26),
#  ('VALEA GOODWILL FOUNDATION', 26),
#  ('J.W. BUSINESS SERVICES INC.', 26),
#  ('JOSEPH AZZOPARDI', 26),
#  ('SYLVIE ERICA HOAREAU-CHOLEWINSKA', 26),
#  ('BLADES BARRY G.', 26),
#  ('FIDEHOLD MANAGEMENT LTD.', 25),
#  ('HUTCHINSON IAN STC.', 25),
#  ('ALLIANCE CORPORATE SERVICES LIMITED', 25),
#  ('ANTHONY CAMILLERI', 25),
#  ('CDA LTD.', 25),
#  ('MARAJ RAMNATH HANSRAJ', 25),
#  ('DORCHESTER INTERNATIONAL INC.', 25),
#  ('CDB LTD.', 25),
#  ('MAGNUS NOMINEES LIMITED', 25),
#  ('ALLEYNE EZRA E.', 25),
#  ('SCIVIAS TRUST MANAGEMENT LIMITED', 25),
#  ('HELM TRUST COMPANY LIMITED', 25),
#  ('ENERVO ADMINISTRATION LIM', 25),
#  ('GITTENS THEODORE D', 25),
#  ('JOSEPH GRECH', 25),
#  ('Edward Petre-Mears', 25),
#  ('LI JUN', 25),
#  ('CMS LIMITED', 25),
#  ('PEMBERTON MICHAEL BARRIE', 25),
#  ('AMICORP CORPORATE SERVICE S (BARBADOS) LTD.', 25),
#  ('BLACKMAN CHRISTOPHER ARTHUR', 25),
#  ('H2R NOMINEE FOUNDATION', 25),
#  ('Stephen Kelly', 25),
#  ('PADDICK BRENDAN J.', 25),
#  ('RUSLAN GORYUKHIN', 25),
#  ('MOSSACK FONSECA & CO. (B.V.I.) LTD.', 25),
#  ('JOSEPH ATTARD', 25),
#  ('Juris Magister (BVI) Ltd.', 25),
#  ('BEXANA CORPORATION', 25),
#  ('H G M SERVICES LIMITED', 25),
#  ('Andreas Thomas Moustras', 25),
#  ('WEATHERHEAD BERNARD ALFREDO', 25),
#  ('KPM Consulting Ltd.', 25),
#  ('TRIDENT CORPORATE SERVICES (BDOS) LTD.', 24),
#  ('KEESTON CORPORATION', 24),
#  ('KIRTON WAYNE H.', 24),
#  ('SCIVIAS TRUST MANAGEMENT LTD', 24),
#  ('LUIS JAVIER CASTRO LACHNER', 24),
#  ('Demetra Stavrinou', 24),
#  ('BOS Nominees (Jersey) Limited', 24),
#  ('REECKMANN S.A.', 24),
#  ('OSS ADVISORS INC.', 24),
#  ('LIU YANG', 24),
#  ('PRITCHARD MARTIN J.K.', 24),
#  ('JOSEPH AGIUS', 24),
#  ('SHOREY DAVID C.', 24),
#  ('Red Shield Nominees Limited', 24),
#  ('BOURNE CARL L.', 24),
#  ('ORBITRON LIMITED', 24),
#  ('GOLLOP FRED W.', 24),
#  ('Regula Limited', 24),
#  ('Edgardo E. Diaz', 24),
#  ('BUSINESS, LTD. GFS', 24),
#  ('Richmond Nominees Limited', 24),
#  ('ALLSOPP JUNIOR O.', 24),
#  ('BLUE SPRUCE FOUNDATION', 24),
#  ('GTC MANAGEMENT LTD.,', 24),
#  ('Executive Nominees (BVI) Ltd', 24),
#  ('AMOS SERVICES S.A.', 24),
#  ('NORRIS JULIAN D.', 24),
#  ('Norma Laurence', 23),
#  ('LEX CARIBBEAN', 23),
#  ('ECS INTERNATIONAL NOMINEES (BVI) LIMITED', 23),
#  ('MILLIGAN SIMON G.', 23),
#  ('BAIRD ONE LIMITED', 23),
#  ('CSUMRIK DAVID G', 23),
#  ('JOSEPH MIFSUD', 23),
#  ('HEWITT MITCHINSON E.S.', 23),
#  ('MURRAY ANDREW D.', 23),
#  ('MARK CAMILLERI', 23),
#  ('BASEL TWO LIMITED', 23),
#  ('JACKMAN ERNEST W.', 23),
#  ('Lerato Makoetlane', 23),
#  ('CHRISTEN MARTIN', 23),
#  ('Irene Knowles', 23),
#  ('JDS SECRETARIES LIMITED', 23),
#  ('GRIMES MICHAEL D.', 23),
#  ('MALONEY MARK ALBERT', 23),
#  ('THORNHILL ANDREW V', 23),
#  ('PATTERSON* PETER MCG.', 23),
#  ('WORME ROBERT C', 23),
#  ('SAIT SALAM GUTSERIEV', 23),
#  ('HUTCHINSON GAYLE A.', 23),
#  ('STEINBOK JEREMIAH', 23),
#  ('MARR ROSEMARY ELIZABETH', 23),
#  ('CAVE ROGER M.', 23),
#  ('KINGSTON PHILIP H.', 23),
#  ('STEVMAR CORPORATE SERVICES LTD', 23),
#  ('COMSEC SERVICES LIMITED', 23),
#  ("GUARDIAN NOMINEES (B'DOS) LIMITED", 23),
#  ('BJERKHAMN BJORN FERDINAND', 23),
#  ('Yuk Wah CHAN NG', 22),
#  ('PIETRO CARENZA', 22),
#  ('MAYERS RODNEY ST.C.', 22),
#  ('CHESTERFIELD NOMINEES LIMITED', 22),
#  ('WALCOTT STEPHEN J.', 22),
#  ('ATHNID LIMITED', 22),
#  ('Andreas T Moustras', 22),
#  ('BELLAMY JOHN G.', 22),
#  ('FYNALIST LIMITED', 22),
#  ('First Court Limited', 22),
#  ('JOSEPH DEBONO', 22),
#  ('BINNEMA HENRY H.', 22),
#  ('GROUPWISE LIMITED', 22),
#  ('AMBASSADOR SECRETARIES LI', 22),
#  ('HIGHLAND RYAN A', 22),
#  ('YEARWOOD VINCENT L.', 22),
#  ('Douglas Mackintosh', 22),
#  ('ANDRI ATHANASIOU', 22),
#  ('Cambridge Hills Ltd', 22),
#  ('CAVE RONALD G.', 22),
#  ('AZTEC HOLDINGS LIMITED', 22),
#  ('KODILINYE LYSTRA A.', 22),
#  ('BLANCHETTE RICHARD A.', 22),
#  ('ANTHONY BORG', 22),
#  ('BRYANT HILDA DIANA', 22),
#  ('SERGEY PUGACHEV', 22),
#  ('LEDGER IAN', 22),
#  ('HOLFORD ROGER S.', 22),
#  ('BRONTE INTERNATIONAL SA', 22),
#  ('Intercon Limited', 22),
#  ('JOSEPH CARUANA', 22),
#  ('MATIAS RODRIGO DE TEZANOS POSSE', 22),
#  ('Michael Garnet Dixon', 21),
#  ('MARIO BORG', 21),
#  ('HAZZARD ALTHEA C.', 21),
#  ('ARTHUR-SELMAN JAMAR P.R.', 21),
#  ('CRUIKSHANK ALLAN B', 21),
#  ('FLETCHER PETER G.', 21),
#  ("O'GORMAN BARBARA A.", 21),
#  ('NEWSAM DOUGLAS A.', 21),
#  ('INNISS DONVILLE O', 21),
#  ('JOHN CAMILLERI', 21),
#  ('BRACE NATALIE MARIE', 21),
#  ('IOSIF SANDLER', 21),
#  ('FAITH FOUNDATION', 21),
#  ('SYMMONDS PETER GLADWYN', 21),
#  ('TAY YEW BENG PETER', 21),
#  ('LI WEI', 21),
#  ('MIREMONT NOMINEES LTD.', 21),
#  ('VITALY YUSUFOV', 21),
#  ('CREDIT SUISSE TRUST LTD.', 21),
#  ('DOUGLAS WILLIAM P A', 21),
#  ('SIMON CRISPIN GROOM', 21),
#  ('GALE BARRY LOUIS VALANCE', 21),
#  ('BTC NOMINEES S.A.', 21),
#  ('YORBAY BUSINESS S.A.', 21),
#  ('JOSEPH PACE', 21),
#  ('SOLIDARITY ALLIANCE FOUNDATION', 21),
#  ('Jason Hughes', 21),
#  ('LA VILLE CORPORATE SERVICES LIMITED', 21),
#  ('UNION BANCAIRE PRIVEE UBP S.A.', 21),
#  ('PLANTATION MANAGEMENT LTD.', 21),
#  ('CORPORATE SECRETARY LIMITED', 21),
#  ('Aster Worldwide Limited', 21),
#  ('GAURAV BURMAN', 21),
#  ('MCDEIGAN-ELDRIDGE RHONDA D.', 21),
#  ('ZHANG YONG', 21),
#  ('DORCHESTER INTERNATIONAL INC', 21),
#  ('HELM MANAGEMENT LIMITED', 21),
#  ('ZHANG JUN', 21),
#  ('TOWNER CHRISTOPHER J. N.', 21),
#  ('JOSEPH PORTELLI', 21),
#  ('HOLOWESKO & COMPANY LIMIT', 21),
#  ('SUOMENLINNA INTER OY', 20),
#  ('LIU NORMAN C.T.', 20),
#  ('UNICO NOMINEES LIMITED', 20),
#  ('PAUL VELLA', 20),
#  ('EDGHILL CHARLES EDWIN', 20),
#  ('Jenny Azolan', 20),
#  ('ANTHONY VELLA', 20),
#  ('CLARKE GILLIAN M. H.', 20),
#  ('BASTIAN MR. ANTOINE', 20),
#  ('CYRUS KIRK E.', 20),
#  ('WANG QI', 20),
#  ('ATLAS TRUST COMPANY (JERSEY) LIMITED', 20),
#  ('NEWBOLD DAVID R.', 20),
#  ('LI FENG', 20),
#  ('BYER TREVOR OSCAR', 20),
#  ('HERALD MANAGEMENT SERVICES LIMITED', 20),
#  ('ANGLO NOMINEES LTD.', 20),
#  ('GTC MANAGEMENT LTD', 20),
#  ('BETHEL OWEN S-M.', 20),
#  ('AMICORP CORPORATE SERVICES (BDOS) LTD.', 20),
#  ('TEMPLE SECRETARIES LIMITED', 20),
#  ('CHANDARIA KAPOOR', 20),
#  ('Red Shield Secretaries Limited', 20),
#  ('EDGHILL RICHARD L.V.', 20),
#  ('SAID GUTSERIEV', 20),
#  ('EDGHILL STEPHEN R.', 20),
#  ('HERALD TRUST COMPANY LIMITED', 20),
#  ('Terthur Trading Limited', 20),
#  ('TURNEY GITTENS CLYDE', 20),
#  ('HAINE S.A.', 20),
#  ('WANG LEI', 20),
#  ('SIMPSON KYFFIN DONALD', 20),
#  ('Damian Calderbank', 20),
#  ('SMITH NEVILLE LER.', 20),
#  ('IOSSIF NATANOVICH SANDLER', 20),
#  ('TRIDENT CORPORATE SERVICE', 20),
#  ('KING GERALD A.', 20),
#  ('BDG MANAGEMENT LTD.,', 20),
#  ('HYDE KEISHA N.', 20),
#  ('Don Di LAM', 20),
#  ('IMPERIAL CORPORATE SERVICES LTD.', 20),
#  ('CALLAGHAN DAVID F', 20),
#  ('NORTH ATLANTIC SERVICES LTD.', 20),
#  ('JOSEPH SAMMUT', 20),
#  ('RAFFLES TOWNSHIP LTD.', 19),
#  ('CHAPMAN STANLEY K', 19),
#  ('JONES ROBERT L.', 19),
#  ('NORDIC INVESTMENT GROUP LIMITED COMPANY', 19),
#  ('KHAN* MOHAMED HAFIZ', 19),
#  ('HINKSON GREGORY E.', 19),
#  ('MATTHEW CHARLES STOKES', 19),
#  ('CARLOS GERMAN CORDERO GONZALEZ', 19),
#  ('BATSON ST. CLAIR A.', 19),
#  ('WILLIAMS RALPH S.', 19),
#  ('STOLLMEYER MARK SCOTT', 19),
#  ('WILLIAMS VERNON A.', 19),
#  ('Geoffrey Taylor', 19),
#  ('IMPERIAL CORPORATE SERVICES LTD', 19),
#  ('FOSTER JOHN DERECK', 19),
#  ('CAMBRIDGE TRUST CO. LIMITED', 19),
#  ('Seletar Limited', 19),
#  ('FORDE SHURLAND M.', 19),
#  ('Genevieve Odette RONA MAGNAN', 19),
#  ('JOSEPH SCICLUNA', 19),
#  ('Volaw Nominees One Limited', 19),
#  ('SCORPIO SECRETARIAL SERVICES LIMITED', 19),
#  ('YEARWOOD ALTHEA C.', 19),
#  ('TRIDENT CORPORATE SERVICES (BARBADOS)', 19),
#  ('MURPHY JOHN GORDON', 19),
#  ('ABRAHAM JORGE HAZOURY TORAL', 19),
#  ('JOHNSON RALPH LANCELOT', 19),
#  ('KELLDYNE LTD.', 19),
#  ('MIDLAND RESOURCES HOLDING LIMITED', 19),
#  ('NEILANDS JOHN DAVID', 19),
#  ('TRIDENT TRUST COMPANY (I.O.M.) LIMITED', 19),
#  ('ANDREW DAMIAN PERL', 19),
#  ('GUSTAVO ALFREDO CISNEROS RENDILES', 19),
#  ('KIRBY ROBERT S.', 19),
#  ('PATEL NAEEM AHMED EBRAHIM', 19),
#  ('SIMPSON KYFFIN DAVID', 19),
#  ('JOSEPH GAUCI', 19),
#  ('ROLLE-TIEDEMANN SUSANNE', 19),
#  ('CIRCLE TRUST LIMITED', 19),
#  ('JOSEPH ABELA', 19),
#  ('Anthony Paul GOLAMCO', 19),
#  ('TOMAS FIALA', 19),
#  ('LEX LTD.', 19),
#  ('WILKINSON JOHN G.', 19),
#  ('APEX NOMINEES 1 LIMITED', 19),
#  ('Gina A. Martinez G.', 19),
#  ('ANDREAS ANASTASIOU', 19),
#  ('BARNES DEBORAH J', 19),
#  ('DATHORNE RONAELE T', 19),
#  ('Alastair Matthew Cunningham', 19),
#  ('Standard Directors Ltd.', 19),
#  ('WILLIAMS CHARLES E.', 19),
#  ('JAMES WINGETT HILL', 19),
#  ('JUPITER NOMINEES ONE S.A.', 19),
#  ('JOHN MICALLEF', 19),
#  ('HARPER JOHN CECIL', 19),
#  ('ABERDEEN FOUNDATION', 19),
#  ('ZHANG HONG', 19),
#  ('TRIDENT TRUST COMPANY LIMITED', 19),
#  ('ATC SECRETARIAL SERVICES INC.', 19),
#  ('Euro-Amex Exchange, Inc.', 19),
#  ('Andreas Ellinas', 19),
#  ('KINCH GEOFFREY ALLAN', 19),
#  ('VICTORY NOMINEES LIMITED', 18),
#  ('Bridgewater Second Nominees Limited', 18),
#  ('Geoffrey Magistrate', 18),
#  ('OLEKSANDR RATSKEVYCH', 18),
#  ('WANG HUI', 18),
#  ('VITALIY NOVASHCHUK', 18),
#  ('CAVERSHAM TRUSTEES LIMITED', 18),
#  ('Primi Limited', 18),
#  ('Sylvie Erica Hoareau-Cholewinska', 18),
#  ('THOMAS BRUCE A', 18),
#  ('ATC FOUNDATION', 18),
#  ('JOSEPH CASSAR', 18),
#  ('Stella G. Port-Louis', 18),
#  ('LI LI', 18),
#  ('MISCHOSITOS INVESTMENT S.A.', 18),
#  ('ZHANG BIN', 18),
#  ('AMATUS CAPITAL GROUP LIMITED COMPANY', 18),
#  ('Obelisk Nominees Limited', 18),
#  ('CUNNINGHAM ALASTAIR MATTHEW', 18),
#  ('(BAHAMAS) LTD. CBT', 18),
#  ('LOTMORE ROBERT V.', 18),
#  ('ANDREW CHARLES WILLIAMS', 18),
#  ('WARREN WENDY', 18),
#  ('VOLODYMYR OSADCHUK', 18),
#  ('PHILLIPS GRENVILLE W.', 18),
#  ('EXECUTIVE DIRECTORS (BVI) LTD', 18),
#  ('ROCK PETER N.', 18),
#  ('Hallmark Management Inc.', 18),
#  ('CHANDLER JEFFREY', 18),
#  ('SUMNER EDISON L.', 18),
#  ('ZHANG JIAN', 18),
#  ('BARROLL BROWN MR. JOHN', 18),
#  ('Andrew Stuart Moray', 18),
#  ('KINGSRIDGE NOMINEES LIMITED', 18),
#  ('TRIDENT CORPORATE SERVICES', 18),
#  ('APEX NOMINEES 2 LIMITED', 18),
#  ('MCLENNAN REX J.', 18),
#  ('WANG HAO', 18),
#  ('JOHN VELLA', 18),
#  ('VERNET EMMANUEL', 18),
#  ('CHRYSOSTOM LEODEAN', 18),
#  ('BREWER COLIN T. O.', 18),
#  ('JONES TONI M.D.', 18),
#  ('WANG YING', 18),
#  ('LEWIS KEITH L.', 18),
#  ('HERMES INTERNATIONAL FOUNDATION', 18),
#  ('FITZWILLIAM MICHAEL N.', 18),
#  ('WORME ROBERT CHARLES', 18),
#  ('IMPERIAL MANAGEMENT SERVICES LTD.', 18),
#  ('WARREN TRUSTEES LIMITED', 18),
#  ('Trex Limited', 18),
#  ('WELFARE RESEARCH FOUNDATION', 18),
#  ('Marco A. SAN BERGUIDO', 18),
#  ('(BARBADOS) INC. SGG MANAGEMENT', 18),
#  ('MARSHALL DALE D.', 18),
#  ('Hamilton Trust Company of South Dakota LLC', 18),
#  ('LEXINTER INTERNATIONAL INC.', 18),
#  ('ALLEYNE IAN A.', 17),
#  ('WILLIAMS GRAFTON N.', 17),
#  ('KENTISH ELNETH OLIVIER', 17),
#  ('BYNOE MICHAEL ROBIN', 17),
#  ('ALEKSANDR MANUZOV', 17),
#  ('Brock Nominees Limited', 17),
#  ('SOROOSH SHAMBAYATI', 17),
#  ('MURRELL SHONTELLE N.', 17),
#  ('COZIER CARL RICHARD', 17),
#  ('GOLLOP FRED WINLYN', 17),
#  ('TREDORIC LIMITED', 17),
#  ('LI JIAN', 17),
#  ('KING GERALD ANTHONY ALLAN', 17),
#  ('JOSEPH FENECH', 17),
#  ('BLADES DENNIS T.', 17),
#  ('DAVIS LARRY A.', 17),
#  ('ZHANG YAN', 17),
#  ('MARTELLO MANAGEMENT LIMITED', 17),
#  ('CARTRUST CORPORATION LIMITED', 17),
#  ('MARIO VELLA', 17),
#  ('CRAMLINGTON LIMITED', 17),
#  ('C.C.S. DIRECTORS LIMITED', 17),
#  ('Annabelle Jean-Louis', 17),
#  ('Second Court Limited', 17),
#  ('ULLYETT MELISSA A.', 17),
#  ('MCNEILLY MATTHEW', 17),
#  ('HUSBANDS CARLSON E.', 17),
#  ('Albert H. Davis', 17),
#  ('TONG ROYCE S.', 17),
#  ('Maria Christofidou', 17),
#  ('ROWE NEVILLE S.', 17),
#  ('GITTENS TERRY V.', 17),
#  ('EVELYN SUSANNAH M.', 17),
#  ('ERNST & YOUNG SERVICES LTD.', 17),
#  ('SAGE INVESTMENTS LTD.', 17),
#  ('ZENITH NOMINEES LIMITED', 17),
#  ('Elaine McGoogan', 17),
#  ('HERBERT ARTHUR CHARLES', 17),
#  ('ABRAHAMS WILFRED ARTHUR', 17),
#  ('HOYOS ELLA N.', 17),
#  ('ALLEYNE JOHN RICHARD', 17),
#  ('Martha Demetriades', 17),
#  ('SMITH NEVILLE L', 17),
#  ('BANFIELD RANDALL IAN', 17),
#  ('LIMITED COURT ADMINISTRATION', 17),
#  ('South Dakota Trust Company LLC', 17),
#  ('LIMITED YORKE SECRETARIES', 17),
#  ('WANG TAO', 17),
#  ('THORNHILL TERRENCE A.', 17),
#  ('BAIN SHONALEE', 17),
#  ('ALEXANDR ZHUKOV', 17),
#  ('FISHER RICHARD A.', 17),
#  ('DIEGO JOSE FERNANDEZ KLOSE', 17),
#  ('Serangoon Limited', 17),
#  ('TATIANA VOZDOVSCAIA', 17),
#  ('LUALDI GIUSEPPINA', 17),
#  ('GEORGE RAMISHVILI', 17),
#  ('MONTAGUE GOLDSMITH INVESTCO ANSTALT', 17),
#  ('Bridgewater First Nominees Limited', 17),
#  ('CASTLE HILL (NOMINEES) LIMITED', 17),
#  ('ALEKSI TOPURIA', 17),
#  ('Sean Hogan', 17),
#  ('Alexander Studhalter', 17),
#  ('HANSCHELL JOHN HOTHER', 17),
#  ('HARRIS VIVEK PETER', 17),
#  ('The Succession Corporation', 17),
#  ('APAKURA LLC.', 17),
#  ('ARRINDELL BERNELL L.', 17),
#  ('Bassim Enterprises Limited', 16),
#  ('KNOTT JAMES M.', 16),
#  ('FINASWISS FOUNDATION', 16),
#  ('JOSEPH AQUILINA', 16),
#  ('Dorchester International Inc.', 16),
#  ('YANG JUN', 16),
#  ('CHRISTIE ADRIAN DEVERE', 16),
#  ('C. B. MANAGEMENT LIMITED', 16),
#  ('FREESTAR NOMINEES LIMITED', 16),
#  ('ECONOMIST INCORPORATED', 16),
#  ('PAYNE LEONARD A', 16),
#  ('Hophil Nominees (BVI) Limited', 16),
#  ('HSBC International Trustee Limited', 16),
#  ('JOHN FARRUGIA', 16),
#  ('MOSCRIP LIMITED', 16),
#  ('GILL STEWART L.', 16),
#  ('CHARLES BORG', 16),
#  ('WELWYN LIMITED', 16),
#  ('WEBER FOUNDATION', 16),
#  ('Gaetanne Antat', 16),
#  ('SUNION SERVICES CORP.', 16),
#  ('ZHANG YI', 16),
#  ('DAVID BORGER', 16),
#  ('KING MAURICE ADRIAN', 16),
#  ('Sean Lee Hogan', 16),
#  ('Finistere Limited', 16),
#  ('SANTO MANAGEMENT LIMITED', 16),
#  ('WHITMILL SECRETARIES LIMITED', 16),
#  ('ZHANG JING', 16),
#  ('JOSEPH SPITERI', 16),
#  ('HARDING DAVID LIONEL', 16),
#  ('IDALECIO DE CASTRO RODRIGUES DE OLIVEIRA', 16),
#  ('CHACKO JACQUELINE R.', 16),
#  ('SERGEY EVSTIFEEV', 16),
#  ('WANG PENG', 16),
#  ('Andri Athanasiou', 16),
#  ('PRICE CLARIS P.J.', 16),
#  ('Athnid Limited', 16),
#  ('SEYMOUR LAURA JANE HILTON', 16),
#  ('EUROSTOCK AG', 16),
#  ('LA VILLE SECRETARIES LIMITED', 16),
#  ('MAYTREE OVERSEAS S.A.', 16),
#  ('Jeffrey Layson', 16),
#  ('GILBERT BERNARD', 16),
#  ('WILLIAMS SIR CHARLES O.', 16),
#  ('A.J.K. WEALTH ADMINISTRAT', 16),
#  ('A.J.K. WEALTH MANAGEMENT', 16),
#  ('CLARKE ROGER E.E.', 16),
#  ('CLEARE ARLENE', 16),
#  ('Damor Investments Limited', 16),
#  ('JOSEPH BONNICI', 16),
#  ('VICTORIA JANE LORAINE', 16),
#  ('MARTELLO TRUST COMPANY LIMITED', 16),
#  ('TOMLIN WILLIAM', 16),
#  ('FINISTERE LIMITED', 16),
#  ('JORGE LUIS FELIZ GERMAN', 16),
#  ('EUROTRADE DIRECTORS LTD.', 16),
#  ('PAUL BORG', 16),
#  ('ZHOU XIN', 16),
#  ('SIMPSON DEBORAH A.', 16),
#  ('ESTWICK RICHARD B.', 16),
#  ('GRANGE NOMINEES LIMITED', 16),
#  ('TOPAZE COMPANY SERVICES S.A.', 16),
#  ('Moores Nominees Limited', 16),
#  ('SMITH CARLOS', 16),
#  ('PAUL CAMILLERI', 16),
#  ('CIDEL CORPORATE SERVICES INC.', 16),
#  ('CERTIDOR LIMITED', 16),
#  ('WALDRON MARLON R.', 16),
#  ('C.C.S. CORPORATE SERVICES LIMITED', 16),
#  ('ANTHONY GRECH', 16),
#  ('QUORUM NOMINEES LIMITED', 16),
#  ('WTG MANAGERS LIMITED', 16),
#  ('WANG YAN', 16),
#  ('SARNIA MANAGEMENT CORP.', 16),
#  ('ELIE DOUER', 16),
#  ('SCIVIAS TRUST MANAGEMENT LTD.', 16),
#  ('JOSEPH VASSALLO', 16),
#  ('GCS LTD', 16),
#  ('THOMPSON DAVID J.H.', 16),
#  ('JOSEPH FALZON', 16),
#  ('EVELYN ALLAN E.P.', 16),
#  ('ACTON CORPORATE SERVICES LIMITED', 16),
#  ('EVELYN SUSANNAH MARIE', 16),
#  ('ABG DIRECTOR INC.', 16),
#  ('GOSSELIN GILLES L', 16),
#  ('MARTINEZ RUAN C.', 16),
#  ('JUPITER NOMINEES TWO S.A.', 16),
#  ('MOSSACK FONSECA & CO. (BVI) LTD.', 16),
#  ('BOLDEN CHARLES LINDSAY', 16),
#  ('CHEN LI', 15),
#  ('BRIGGS GRAEME', 15),
#  ('JOSEPH GATT', 15),
#  ('JOSEPH SCHEMBRI', 15),
#  ('FIRST NAMES ONE LIMITED Former Name FIRST NAMES NOMINEES (C.I.) LIMITED',
#   15),
#  ('HANTON TERENCE M.', 15),
#  ('COLE HAROLD BRIAN', 15),
#  ('PATEL NAEEM A.E.', 15)]

# %% [markdown]
# Now add a `vague` column to flag the dubious names

# %%
df["vague"] = df.apply(lambda x: not filter_bearer(x["name"]), axis = 1)

# %% [markdown]
# Keep track of the set of `node_id` values for this class.

# %%
id_officer: set = set(df[df.vague == False].node_id.values)

# %% [markdown]
# Reshape the dataframe to fit our inclusive `Entity` metadata.

# %%
df.columns.values.tolist()
# Out:
# ['node_id',
#  'name',
#  'countries',
#  'country_codes',
#  'sourceID',
#  'valid_until',
#  'note',
#  'vague']

# %%
df.insert(1, "role", "Officer")

df.insert(3, "original_name", "")
df.insert(4, "former_name", "")
df.insert(5, "jurisdiction", "")
df.insert(6, "jurisdiction_description", "")
df.insert(7, "company_type", "")
df.insert(8, "address", "")
df.insert(9, "internal_id", "")
df.insert(10, "incorporation_date", "")
df.insert(11, "inactivation_date", "")
df.insert(12, "struck_off_date", "")
df.insert(13, "dorm_date", "")
df.insert(14, "status", "")
df.insert(15, "service_provider", "")
df.insert(16, "ibcRUC", "")

# %%
columns: list = list(df.columns.values)

columns[17] = "country_codes"
columns[18] = "countries"

columns
# Out:
# ['node_id',
#  'role',
#  'name',
#  'original_name',
#  'former_name',
#  'jurisdiction',
#  'jurisdiction_description',
#  'company_type',
#  'address',
#  'internal_id',
#  'incorporation_date',
#  'inactivation_date',
#  'struck_off_date',
#  'dorm_date',
#  'status',
#  'service_provider',
#  'ibcRUC',
#  'country_codes',
#  'countries',
#  'sourceID',
#  'valid_until',
#  'note',
#  'vague']

# %%
df = df.reindex(columns = columns)
df.head()
# Out:
#     node_id     role                  name original_name former_name  \
# 0  12000001  Officer            KIM SOO IN
# 1  12000002  Officer             Tian Yuan
# 2  12000003  Officer  GREGORY JOHN SOLOMON
# 3  12000004  Officer        MATSUDA MASUMI
# 4  12000005  Officer           HO THUY NGA
#
#   jurisdiction jurisdiction_description company_type address internal_id  ...  \
# 0                                                                         ...
# 1                                                                         ...
# 2                                                                         ...
# 3                                                                         ...
# 4                                                                         ...
#
#   dorm_date status service_provider ibcRUC country_codes    countries  \
# 0                                                    KOR  South Korea
# 1                                                    CHN        China
# 2                                                    AUS    Australia
# 3                                                    JPN        Japan
# 4                                                    VNM     Viet Nam
#
#         sourceID                                     valid_until note  vague
# 0  Panama Papers  The Panama Papers data is current through 2015       False
# 1  Panama Papers  The Panama Papers data is current through 2015       False
# 2  Panama Papers  The Panama Papers data is current through 2015       False
# 3  Panama Papers  The Panama Papers data is current through 2015       False
# 4  Panama Papers  The Panama Papers data is current through 2015       False
#
# [5 rows x 23 columns]

# %%
conn.execute(
    "COPY Entity FROM (LOAD FROM df RETURN *)"
);

# %%
results = conn.execute("""
  MATCH (n:Entity)
  RETURN COUNT(*)
""")

while results.has_next():
    ic(results.get_next())
# Out:
# ic| results.get_next(): [1585659]

# %% [markdown]
# ### Intermediaries

# %%
dat_file: pathlib.Path = dat_dir / "nodes-intermediaries.csv"

df = pd.read_csv(
    dat_file,
    header = 0,
    low_memory = False,
).astype(str).fillna("")

df.replace({"nan": ""}, regex=True, inplace=True)

df.head()
# Out:
#     node_id                        name     status internal_id  \
# 0  11000001     MICHAEL PAPAGEORGE, MR.     ACTIVE       10001
# 1  11000002          CORFIDUCIA ANSTALT     ACTIVE       10004
# 2  11000003               DAVID, RONALD  SUSPENDED       10014
# 3  11000004  DE  BOUTSELIS, JEAN-PIERRE  SUSPENDED       10015
# 4  11000005    THE LEVANT LAWYERS (TLL)     ACTIVE       10029
#
#                                              address      countries  \
# 0  MICHAEL PAPAGEORGE; MR. 106 NICHOLSON STREET B...   South Africa
# 1                                                     Liechtenstein
# 2                                                            Monaco
# 3                                                           Belgium
# 4                                                           Lebanon
#
#   country_codes       sourceID  \
# 0           ZAF  Panama Papers
# 1           LIE  Panama Papers
# 2           MCO  Panama Papers
# 3           BEL  Panama Papers
# 4           LBN  Panama Papers
#
#                                        valid_until note
# 0  The Panama Papers  data is current through 2015
# 1  The Panama Papers  data is current through 2015
# 2  The Panama Papers  data is current through 2015
# 3  The Panama Papers  data is current through 2015
# 4  The Panama Papers  data is current through 2015

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#          node_id                 name status internal_id address  countries  \
# count      26768                26768  26768       26768   26768      26768
# freq           1                   62  14147       12117   18125       4895
# unique     26768                25590     10       14282    8640        286
# top     11000001  HUTCHINSON GAYLE A.                             Hong Kong
#
#        country_codes       sourceID  \
# count          26768          26768
# freq            4895          14110
# unique           286              9
# top              HKG  Panama Papers
#
#                                             valid_until   note
# count                                             26768  26768
# freq                                              14110  26761
# unique                                               11      7
# top     The Panama Papers  data is current through 2015

# %% [markdown]
# The `Intermediaries` defined by ICIJ have loads of overlapping records. These need to be removed.

# %%
len(id_officer.intersection(set(df.node_id.values)))
# Out:
# 1139

# %%
def check_row (
    node_id: int,
    ) -> bool:
    return node_id not in id_officer

df["keep"] = df.apply(lambda x: check_row(x["node_id"]), axis = 1)
df = df[df.keep]
del df["keep"]

len(id_officer.intersection(set(df.node_id.values)))
# Out:
# 0

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#          node_id                 name status internal_id address  countries  \
# count      25629                25629  25629       25629   25629      25629
# freq           1                   62  13008       10978   16986       4719
# unique     25629                24463     10       14282    8640        279
# top     11000001  HUTCHINSON GAYLE A.                             Hong Kong
#
#        country_codes       sourceID  \
# count          25629          25629
# freq            4719          14110
# unique           279              9
# top              HKG  Panama Papers
#
#                                             valid_until   note
# count                                             25629  25629
# freq                                              14110  25622
# unique                                               11      7
# top     The Panama Papers  data is current through 2015

# %% [markdown]
# Keep track of the set of `node_id` values for this class.

# %%
id_intermed: set = set(df.node_id.values)

# %% [markdown]
# Reshape the dataframe to fit our inclusive `Entity` metadata.

# %%
df.columns.values.tolist()
# Out:
# ['node_id',
#  'name',
#  'status',
#  'internal_id',
#  'address',
#  'countries',
#  'country_codes',
#  'sourceID',
#  'valid_until',
#  'note']

# %%
df.insert(1, "role", "Intermediary")

df.insert(3, "original_name", "")
df.insert(4, "former_name", "")
df.insert(5, "jurisdiction", "")
df.insert(6, "jurisdiction_description", "")
df.insert(7, "company_type", "")

df.insert(11, "incorporation_date", "")
df.insert(12, "inactivation_date", "")
df.insert(13, "struck_off_date", "")
df.insert(14, "dorm_date", "")

df.insert(15, "service_provider", "")
df.insert(16, "ibcRUC", "")

df["vague"] = False

# %%
df.columns.values.tolist()
# Out:
# ['node_id',
#  'role',
#  'name',
#  'original_name',
#  'former_name',
#  'jurisdiction',
#  'jurisdiction_description',
#  'company_type',
#  'status',
#  'internal_id',
#  'address',
#  'incorporation_date',
#  'inactivation_date',
#  'struck_off_date',
#  'dorm_date',
#  'service_provider',
#  'ibcRUC',
#  'countries',
#  'country_codes',
#  'sourceID',
#  'valid_until',
#  'note',
#  'vague']

# %%
columns: list = list(df.columns.values)

columns.remove("address")
columns.insert(9, "address")

columns.remove("status")
columns.insert(14, "status")

columns[17] = "country_codes"
columns[18] = "countries"

columns
# Out:
# ['node_id',
#  'role',
#  'name',
#  'original_name',
#  'former_name',
#  'jurisdiction',
#  'jurisdiction_description',
#  'company_type',
#  'address',
#  'internal_id',
#  'incorporation_date',
#  'inactivation_date',
#  'struck_off_date',
#  'dorm_date',
#  'status',
#  'service_provider',
#  'ibcRUC',
#  'country_codes',
#  'countries',
#  'sourceID',
#  'valid_until',
#  'note',
#  'vague']

# %%
df = df.reindex(columns = columns)
df.head()
# Out:
#     node_id          role                        name original_name  \
# 0  11000001  Intermediary     MICHAEL PAPAGEORGE, MR.
# 1  11000002  Intermediary          CORFIDUCIA ANSTALT
# 2  11000003  Intermediary               DAVID, RONALD
# 3  11000004  Intermediary  DE  BOUTSELIS, JEAN-PIERRE
# 4  11000005  Intermediary    THE LEVANT LAWYERS (TLL)
#
#   former_name jurisdiction jurisdiction_description company_type  \
# 0
# 1
# 2
# 3
# 4
#
#                                              address internal_id  ...  \
# 0  MICHAEL PAPAGEORGE; MR. 106 NICHOLSON STREET B...       10001  ...
# 1                                                          10004  ...
# 2                                                          10014  ...
# 3                                                          10015  ...
# 4                                                          10029  ...
#
#   dorm_date     status service_provider ibcRUC country_codes      countries  \
# 0               ACTIVE                                   ZAF   South Africa
# 1               ACTIVE                                   LIE  Liechtenstein
# 2            SUSPENDED                                   MCO         Monaco
# 3            SUSPENDED                                   BEL        Belgium
# 4               ACTIVE                                   LBN        Lebanon
#
#         sourceID                                      valid_until note  vague
# 0  Panama Papers  The Panama Papers  data is current through 2015       False
# 1  Panama Papers  The Panama Papers  data is current through 2015       False
# 2  Panama Papers  The Panama Papers  data is current through 2015       False
# 3  Panama Papers  The Panama Papers  data is current through 2015       False
# 4  Panama Papers  The Panama Papers  data is current through 2015       False
#
# [5 rows x 23 columns]

# %%
conn.execute(
    "COPY Entity FROM (LOAD FROM df RETURN *)"
);

# %% [markdown]
# ### Others

# %%
dat_file: pathlib.Path = dat_dir / "nodes-others.csv"
df = pd.read_csv(dat_file, header = 0).astype(str).fillna("")
df.replace({"nan": ""}, regex=True, inplace=True)

df.head()
# Out:
#     node_id                               name                       type  \
# 0  85004929             ANTAM ENTERPRISES N.V.  LIMITED LIABILITY COMPANY
# 1  85008443                     DEVIATION N.V.  LIMITED LIABILITY COMPANY
# 2  85008517                        ARIAZI N.V.  LIMITED LIABILITY COMPANY
# 3  85008542                      FLAIRUBA N.V.  LIMITED LIABILITY COMPANY
# 4  85008583  S.L. ARUBA FISHERIES TRADING N.V.  LIMITED LIABILITY COMPANY
#
#   incorporation_date struck_off_date  closed_date jurisdiction  \
# 0        18-MAY-1983                  28-NOV-2012           AW
# 1        28-JUN-1989     31-DEC-2002                        AW
# 2        19-JUL-1989                  19-MAY-2004           AW
# 3        27-JUL-1989     24-JUL-2000                        AW
# 4        01-AUG-1989                  29-OCT-2007           AW
#
#   jurisdiction_description countries country_codes  \
# 0                    Aruba
# 1                    Aruba
# 2                    Aruba
# 3                    Aruba
# 4                    Aruba
#
#                                      sourceID  \
# 0  Paradise Papers - Aruba corporate registry
# 1  Paradise Papers - Aruba corporate registry
# 2  Paradise Papers - Aruba corporate registry
# 3  Paradise Papers - Aruba corporate registry
# 4  Paradise Papers - Aruba corporate registry
#
#                                          valid_until  \
# 0  Aruba corporate registry data is current throu...
# 1  Aruba corporate registry data is current throu...
# 2  Aruba corporate registry data is current throu...
# 3  Aruba corporate registry data is current throu...
# 4  Aruba corporate registry data is current throu...
#
#                                      note
# 0  Closed date stands for Cancelled date.
# 1
# 2  Closed date stands for Cancelled date.
# 3
# 4  Closed date stands for Cancelled date.

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#          node_id                           name  type incorporation_date  \
# count       2989                           2989  2989               2989
# freq           1                              3  2101               2101
# unique      2989                           2976     4                835
# top     85004929  Shampaign Investments Limited
#
#        struck_off_date closed_date jurisdiction jurisdiction_description  \
# count             2989        2989         2989                     2989
# freq              2944        2872         2031                     2031
# unique              40         113            7                        7
# top
#
#        countries country_codes                   sourceID  \
# count       2989          2989                       2989
# freq        2603          2603                       2031
# unique        64            64                          7
# top                             Paradise Papers - Appleby
#
#                                  valid_until  note
# count                                   2989  2989
# freq                                    2031  2872
# unique                                    10     3
# top     Appleby data is current through 2014

# %% [markdown]
# Show that the `type` field values are similar to `Entity.company_type`

# %%
set(df.type.values)
# Out:
# {'',
#  'FOREIGN FORMED CORPORATION',
#  'LIMITED LIABILITY COMPANY',
#  'SOLE OWNERSHIP'}

# %% [markdown]
# Keep track of the set of `node_id` values for this class.

# %%
id_other: set = set(df.node_id.values)

# %% [markdown]
# Reshape the dataframe to fit our inclusive `Entity` metadata.

# %%
df.columns.values.tolist()
# Out:
# ['node_id',
#  'name',
#  'type',
#  'incorporation_date',
#  'struck_off_date',
#  'closed_date',
#  'jurisdiction',
#  'jurisdiction_description',
#  'countries',
#  'country_codes',
#  'sourceID',
#  'valid_until',
#  'note']

# %%
df.insert(1, "role", "Other")

df.insert(3, "original_name", "")
df.insert(4, "former_name", "")

df.rename(columns = { "type": "company_type" }, inplace = True)

df.insert(6, "address", "")
df.insert(7, "internal_id", "")

df.rename(columns = { "closed_date": "inactivation_date" }, inplace = True)
df.insert(13, "dorm_date", "")
df.insert(14, "status", "")
df.insert(15, "service_provider", "")
df.insert(16, "ibcRUC", "")

df["vague"] = False

# %%
columns: list = list(df.columns.values)

columns.remove("jurisdiction")
columns.remove("jurisdiction_description")
columns.insert(5, "jurisdiction")
columns.insert(6, "jurisdiction_description")

columns[11] = "inactivation_date"
columns[12] = "struck_off_date"

columns[17] = "country_codes"
columns[18] = "countries"

columns
# Out:
# ['node_id',
#  'role',
#  'name',
#  'original_name',
#  'former_name',
#  'jurisdiction',
#  'jurisdiction_description',
#  'company_type',
#  'address',
#  'internal_id',
#  'incorporation_date',
#  'inactivation_date',
#  'struck_off_date',
#  'dorm_date',
#  'status',
#  'service_provider',
#  'ibcRUC',
#  'country_codes',
#  'countries',
#  'sourceID',
#  'valid_until',
#  'note',
#  'vague']

# %%
df = df.reindex(columns = columns)
df.head()
# Out:
#     node_id   role                               name original_name  \
# 0  85004929  Other             ANTAM ENTERPRISES N.V.
# 1  85008443  Other                     DEVIATION N.V.
# 2  85008517  Other                        ARIAZI N.V.
# 3  85008542  Other                      FLAIRUBA N.V.
# 4  85008583  Other  S.L. ARUBA FISHERIES TRADING N.V.
#
#   former_name jurisdiction jurisdiction_description  \
# 0                       AW                    Aruba
# 1                       AW                    Aruba
# 2                       AW                    Aruba
# 3                       AW                    Aruba
# 4                       AW                    Aruba
#
#                 company_type address internal_id  ... dorm_date status  \
# 0  LIMITED LIABILITY COMPANY                      ...
# 1  LIMITED LIABILITY COMPANY                      ...
# 2  LIMITED LIABILITY COMPANY                      ...
# 3  LIMITED LIABILITY COMPANY                      ...
# 4  LIMITED LIABILITY COMPANY                      ...
#
#   service_provider ibcRUC country_codes countries  \
# 0
# 1
# 2
# 3
# 4
#
#                                      sourceID  \
# 0  Paradise Papers - Aruba corporate registry
# 1  Paradise Papers - Aruba corporate registry
# 2  Paradise Papers - Aruba corporate registry
# 3  Paradise Papers - Aruba corporate registry
# 4  Paradise Papers - Aruba corporate registry
#
#                                          valid_until  \
# 0  Aruba corporate registry data is current throu...
# 1  Aruba corporate registry data is current throu...
# 2  Aruba corporate registry data is current throu...
# 3  Aruba corporate registry data is current throu...
# 4  Aruba corporate registry data is current throu...
#
#                                      note  vague
# 0  Closed date stands for Cancelled date.  False
# 1                                          False
# 2  Closed date stands for Cancelled date.  False
# 3                                          False
# 4  Closed date stands for Cancelled date.  False
#
# [5 rows x 23 columns]

# %%
conn.execute(
    "COPY Entity FROM (LOAD FROM df RETURN *)"
);

# %%
results = conn.execute("""
  MATCH (n:Entity)
  RETURN COUNT(*)
""")

while results.has_next():
    ic(results.get_next())
# Out:
# ic| results.get_next(): [1614277]

# %% [markdown]
# ### Addresses

# %%
dat_file: pathlib.Path = dat_dir / "nodes-addresses.csv"

df = pd.read_csv(
    dat_file,
    header = 0,
    low_memory = False,
).astype(str).fillna("")

df.replace({"nan": ""}, regex=True, inplace=True)

df.head()
# Out:
#     node_id                                            address name countries  \
# 0  24000001  ANNEX FREDERICK & SHIRLEY STS, P.O. BOX N-4805...        Bahamas
# 1  24000002  SUITE E-2,UNION COURT BUILDING, P.O. BOX N-818...        Bahamas
# 2  24000003  LYFORD CAY HOUSE, LYFORD CAY, P.O. BOX N-7785,...        Bahamas
# 3  24000004  P.O. BOX N-3708 BAHAMAS FINANCIAL CENTRE, P.O....        Bahamas
# 4  24000005  LYFORD CAY HOUSE, 3RD FLOOR, LYFORD CAY, P.O. ...        Bahamas
#
#   country_codes       sourceID  \
# 0           BHS  Bahamas Leaks
# 1           BHS  Bahamas Leaks
# 2           BHS  Bahamas Leaks
# 3           BHS  Bahamas Leaks
# 4           BHS  Bahamas Leaks
#
#                                          valid_until note
# 0  The Bahamas Leaks data is current through earl...
# 1  The Bahamas Leaks data is current through earl...
# 2  The Bahamas Leaks data is current through earl...
# 3  The Bahamas Leaks data is current through earl...
# 4  The Bahamas Leaks data is current through earl...

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#          node_id address    name countries country_codes  \
# count     402246  402246  402246    402246        402246
# freq           1   19932  178898    125335        125335
# unique    402246  377861  222810       366           226
# top     24000001
#
#                                           sourceID  \
# count                                       402246
# freq                                        123269
# unique                                          20
# top     Paradise Papers - Malta corporate registry
#
#                                               valid_until    note
# count                                              402246  402246
# freq                                               123269  402208
# unique                                                 26      12
# top     Malta corporate registry data is current throu...

# %% [markdown]
# Keep track of the set of `node_id` values for this class.

# %%
id_address: set = set(df.node_id.values)

# %%
df.columns.values.tolist()
# Out:
# ['node_id',
#  'address',
#  'name',
#  'countries',
#  'country_codes',
#  'sourceID',
#  'valid_until',
#  'note']

# %%
conn.execute("""
  CREATE NODE TABLE Address (
    node_id STRING,
    address STRING,
    name STRING,
    countries STRING,
    country_codes STRING,
    sourceID STRING,
    valid_until STRING,
    note STRING,
    PRIMARY KEY (node_id)
  )
""");

# %%
conn.execute(
    "COPY Address FROM (LOAD FROM df RETURN *)"
);

# %%
results = conn.execute("""
  MATCH (n:Address)
  RETURN *
  LIMIT 1;
""")

while results.has_next():
    ic(results.get_next())
# Out:
# ic| results.get_next(): [{'_id': {'offset': 0, 'table': 1},
#                           '_label': 'Address',
#                           'address': '7 Mair Mills Dr.; Collingwood; ON; L9Y0A8; Canada',
#                           'countries': 'Canada',
#                           'country_codes': 'CAN',
#                           'name': '',
#                           'node_id': '14022522',
#                           'note': '',
#                           'sourceID': 'Panama Papers',
#                           'valid_until': 'The Panama Papers  data is current through 2015'}]

# %% [markdown]
# ## Connecting entities

# %% [markdown]
# ### Relationships

# %%
dat_file: pathlib.Path = dat_dir / "relationships.csv"

df = pd.read_csv(
    dat_file,
    header = 0,
    low_memory = False,
).astype(str).fillna("")

df.replace({"nan": ""}, regex=True, inplace=True)

df.head()
# Out:
#   node_id_start node_id_end            rel_type  \
# 0      10000035    14095990  registered_address
# 1      10000044    14091035  registered_address
# 2      10000055    14095990  registered_address
# 3      10000063    10007006             same_as
# 4      10000064    14091429  registered_address
#
#                                  link status start_date end_date  \
# 0                  registered address
# 1                  registered address
# 2                  registered address
# 3  same name and registration date as
# 4                  registered address
#
#         sourceID
# 0  Panama Papers
# 1  Panama Papers
# 2  Panama Papers
# 3
# 4  Panama Papers

# %%
df.describe(include = "all").loc[[ "count", "freq", "unique", "top", ]]
# Out:
#        node_id_start node_id_end    rel_type            link   status  \
# count        3339267     3339267     3339267         3339267  3339267
# freq           36373       37338     1720357          589938  3164321
# unique       1131496     1321323          14            1041        3
# top            54662      236724  officer_of  shareholder of
#
#        start_date end_date                                    sourceID
# count     3339267  3339267                                     3339267
# freq      2392562  3070400                                      776335
# unique      24336    13561                                          12
# top                         Paradise Papers - Malta corporate registry

# %%
df.columns.values.tolist()
# Out:
# ['node_id_start',
#  'node_id_end',
#  'rel_type',
#  'link',
#  'status',
#  'start_date',
#  'end_date',
#  'sourceID']

# %% [markdown]
# Double-check: which `node_id` values exist in the `Entity` node table?

# %%
results = conn.execute("""
  MATCH (n:Entity)
  RETURN n.node_id;
""")

id_ents: set = set()

while results.has_next():
    row: list = results.get_next()
    id_ents.add(row[0])

len(id_ents)
# Out:
# 1614277

# %% [markdown]
# Note: which relations are named in ICIJ?

# %%
rels: dict = df["rel_type"].value_counts().to_dict()
rels
# Out:
# {'officer_of': 1720357,
#  'registered_address': 832721,
#  'intermediary_of': 598546,
#  'same_name_as': 104170,
#  'similar': 46761,
#  'same_company_as': 15523,
#  'connected_to': 12145,
#  'same_as': 4272,
#  'same_id_as': 3120,
#  'underlying': 1308,
#  'similar_company_as': 203,
#  'probably_same_officer_as': 132,
#  'same_address_as': 5,
#  'same_intermediary_as': 4}

# %% [markdown]
# This parts gets a bit iffy. There's already been some entity resolution performed, however's this appears to be simply fuzzy string matching on names and addresses. Als, the pre-defined relations are haphazard in terms of domain/range -- and while Neo4j may be forgiving in this aspect of semantic modeling, this artifact may degrade inference downstream.
#
# This is where the _semantic model_ used by ICIJ seems to be messy. It may produce useful visualizations and graph query results; however, good luck trying to use this for inference downstream!
#
# We want to do better. For now we'll skip the questionable relations which were used in the ICIJ/Neo4j collaboration:
#
#   1. `officer_of`: source nodes with names which are legal placeholders, e.g., "THE BEARER"
#   2. `registered_address`: note that some `Entity` nodes have more than one registered address
#   3. `intermediary_of`: the domain and range are a jumble of `Entity`, `Officer`, `Intermediary`
#   4. `Officer` and `Intermediary` overlap; the former has more information
#   5. `same_company_as`: simple string matches, where the domain and range are sometimes mistakingly representing companies `Officer` nodes
#   6. `probably_same_officer_as`: simple string matches
#   7. (tbd)

# %% [markdown]
# #### OfficerOf

# %% [markdown]
# Link `Officer` nodes to `Entity` nodes using the `OfficerOf` relation

# %%
df[df.rel_type == "officer_of"].head()
# Out:
#        node_id_start node_id_end    rel_type            link status  \
# 221749      12000001    10073324  officer_of  shareholder of
# 221751      12000002    10148386  officer_of  shareholder of
# 221753      12000003    10024966  officer_of  shareholder of
# 221755      12000004    10004763  officer_of  shareholder of
# 221757      12000005    10206741  officer_of  shareholder of
#
#          start_date     end_date       sourceID
# 221749  19-NOV-1999  04-JUL-2000  Panama Papers
# 221751  30-MAR-2012  06-JUL-2012  Panama Papers
# 221753  14-JAN-2010               Panama Papers
# 221755  23-JUL-2012               Panama Papers
# 221757  13-SEP-2010               Panama Papers

# %%
def check_row (
    node_id_start: int,
    node_id_end: int,
    rel_type: str,
    ) -> bool:
    return rel_type == "officer_of" and node_id_start in id_officer and node_id_end in id_entity

df["todo"] = df.apply(lambda x: check_row(x["node_id_start"], x["node_id_end"], x["rel_type"]), axis = 1)

df_todo = df[df.todo]
del df_todo["rel_type"]
del df_todo["todo"]

df_todo
# Out:
#         node_id_start node_id_end                                        link  \
# 221749       12000001    10073324                              shareholder of
# 221751       12000002    10148386                              shareholder of
# 221753       12000003    10024966                              shareholder of
# 221755       12000004    10004763                              shareholder of
# 221757       12000005    10206741                              shareholder of
# ...               ...         ...                                         ...
# 3339244     240556390   240554206                        Beneficiary of trust
# 3339245     240556391   240554207  Beneficial owner of the underlying company
# 3339246     240556392   240554207  Beneficial owner of the underlying company
# 3339247     240556393   240554208                                     Settlor
# 3339248     240556394   240554209  Beneficial owner of the underlying company
#
#         status   start_date     end_date       sourceID
# 221749          19-NOV-1999  04-JUL-2000  Panama Papers
# 221751          30-MAR-2012  06-JUL-2012  Panama Papers
# 221753          14-JAN-2010               Panama Papers
# 221755          23-JUL-2012               Panama Papers
# 221757          13-SEP-2010               Panama Papers
# ...        ...          ...          ...            ...
# 3339244
# 3339245
# 3339246
# 3339247
# 3339248
#
# [1625161 rows x 7 columns]

# %%
conn.execute("""
  CREATE REL TABLE OfficerOf (FROM Entity TO Entity,
    link STRING,
    status STRING,
    start_date STRING,
    end_date STRING,
    sourceID STRING,
    MANY_MANY
  )
""");

# %%
conn.execute(
    "COPY OfficerOf FROM (LOAD FROM df_todo RETURN *)"
);
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[92], line 1
# ----> 1 conn.execute(
#       2     "COPY OfficerOf FROM (LOAD FROM df_todo RETURN *)"
#       3 );
#
# File ~/src/ERKG/icij/venv/lib/python3.11/site-packages/kuzu/connection.py:131, in Connection.execute(self, query, parameters)
#     128     raise RuntimeError(msg)  # noqa: TRY004
#     130 if len(parameters) == 0:
# --> 131     _query_result = self._connection.query(query)
#     132 else:
#     133     prepared_statement = self.prepare(query) if isinstance(query, str) else query
#
# RuntimeError: Runtime exception: Unable to find primary key value 86017926.

# %%
"86017926" in id_officer
# Out:
# True

# %%
df_todo[df_todo.node_id_start == "86017926"]
# Out:
#         node_id_start node_id_end      link status   start_date end_date  \
# 2023779      86017926    85023302  proxy of         06-APR-2001
#
#                                            sourceID
# 2023779  Paradise Papers - Aruba corporate registry

# %%
"86017926" in id_ents
# Out:
# True

# %% [markdown]
# #### IntermediaryOf

# %% [markdown]
# Link `Entity`, `Officer`, `Intermediary` nodes together using the `Intermediary` relation

# %%
df[df.rel_type == "intermediary_of"].head()

# %%
id_entish = id_entity.union(id_officer).union(id_intermed).union(id_other)

def check_row (
    node_id_start: int,
    node_id_end: int,
    rel_type: str,
    ) -> bool:
    return rel_type == "intermediary_of" and node_id_start in id_entish and node_id_end in id_entish

df["todo"] = df.apply(lambda x: check_row(x["node_id_start"], x["node_id_end"], x["rel_type"]), axis = 1)

df_todo = df[df.todo]
del df_todo["rel_type"]
del df_todo["todo"]

df_todo

# %%
conn.execute("""
  CREATE REL TABLE IntermediaryOf (FROM Entity TO Entity,
    link STRING,
    status STRING,
    start_date STRING,
    end_date STRING,
    sourceID STRING,
    MANY_ONE
  )
""");

# %%
conn.execute(
    "COPY IntermediaryOf FROM (LOAD FROM df_todo RETURN *)"
);

# %% [markdown]
# #### RegisteredAddress

# %% [markdown]
# Link `Entity` nodes to `Address` nodes using the `RegisteredAddress` relation

# %%
df[df.rel_type == "registered_address"].head()

# %%
def check_row (
    node_id_start: int,
    node_id_end: int,
    rel_type: str,
    ) -> bool:
    return rel_type == "registered_address" and node_id_start in id_entish and node_id_end in id_address

df["todo"] = df.apply(lambda x: check_row(x["node_id_start"], x["node_id_end"], x["rel_type"]), axis = 1)

df_todo = df[df.todo]
del df_todo["rel_type"]
del df_todo["todo"]

df_todo

# %%
conn.execute("""
  CREATE REL TABLE RegisteredAddress (FROM Entity TO Address,
    link STRING,
    status STRING,
    start_date STRING,
    end_date STRING,
    sourceID STRING,
    MANY_MANY
  )
""");

# %%
conn.execute(
    "COPY RegisteredAddress FROM (LOAD FROM df_todo RETURN *)"
);
